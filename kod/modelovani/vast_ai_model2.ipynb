# %%
import os
import sys
from pathlib import Path
import polars as pl
import pandas as pd
import numpy as np
import gc
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss, confusion_matrix, classification_report, precision_recall_curve, balanced_accuracy_score, matthews_corrcoef, average_precision_score, ConfusionMatrixDisplay
from sklearn.model_selection import ParameterSampler
import matplotlib.pyplot as plt
import seaborn as sns
import json

SEED=42

# %% [markdown]
# # 1. Načtení dat

# %%
lf_prohlidky = pl.scan_parquet(r"prohlidky_model.parquet")
lf_mereni = pl.scan_parquet(r"mereni_model_raw.parquet")
df = lf_prohlidky.join(lf_mereni, on='CisloProtokolu', how='inner').collect().with_columns(pl.col(['Prohlidka_OdpovednaOsoba', 'Prohlidka_Stanice_Cislo', 'Emise_OdpovednaOsoba']).cast(pl.String))

# %% [markdown]
# # 2. Definice proměnných

# %%
id_col = 'CisloProtokolu'
target_col = 'Vysledek_Pristi'

# Identifikace sloupců
all_cols = df.columns
feature_cols = [c for c in all_cols if c not in [id_col, target_col]]

# Automatická detekce kategorických a numerických sloupců
cat_features = [c for c in feature_cols if df[c].dtype in [pl.String, pl.Boolean, pl.Categorical]]
num_features = [c for c in feature_cols if df[c].dtype in [pl.Float32, pl.Float64, pl.Int32, pl.Int8, pl.UInt32]]

# %% [markdown]
# # 3. Typová optimalizace (Polars) pro minimalizaci

# %%
df = df.with_columns([
    pl.col(c).cast(pl.Float32) for c in num_features
]).with_columns([
    pl.col(c).cast(pl.String).fill_null("missing") for c in cat_features
]).with_columns(
    # Inverze zajistí, že 1 = Neúspěch.
    (1 - pl.col(target_col)).cast(pl.Int8).alias(target_col)
)

# %% [markdown]
# # 4. Konverze do Pandas

# %%
# ID sloupec je vyřazen z trénovacích dat
df_pd = df.select(feature_cols + [target_col]).to_pandas()

# Odstranění Polars DataFrame z paměti
del df
_ = gc.collect()

# %% [markdown]
# # 5. Rozdělení dat (Train 80 %, Val 10 %, Test 10 %) se stratifikací

# %%
X = df_pd[feature_cols]
y = df_pd[target_col]

X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.10, random_state=SEED, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.1111, random_state=SEED, stratify=y_temp)

# Odstranění dočasných proměnných
del df_pd, X, y, X_temp, y_temp
_ = gc.collect()

# %% [markdown]
# # 6. Inicializace objektů Pool

# %%
# Převedení dat do interního formátu CatBoost zefektivní využití paměti na GPU
train_pool = Pool(X_train, y_train, cat_features=cat_features)
val_pool = Pool(X_val, y_val, cat_features=cat_features)
test_pool = Pool(X_test, y_test, cat_features=cat_features)

# %% [markdown]
# # 7. Konfigurace a trénování modelu

# %%
DROP_RATIO = 0.1
PATIENCE = 2
MIN_FEATURES = 5

param_grid = {
    'learning_rate': [0.03, 0.05, 0.1],
    'depth': [6, 8],
    'l2_leaf_reg': [1, 3, 5]
}

current_features = feature_cols.copy()
initial_feature_count = len(current_features)

best_overall_model = None
best_overall_f1 = 0
best_overall_thr = 0.5
best_overall_features = []

step = 1
patience_counter = 0

while len(current_features) >= MIN_FEATURES:
    print(f"\n=== Iterace {step} ===")
    print(f"Počet příznaků: {len(current_features)}")

    current_cat_features = [c for c in cat_features if c in current_features]

    train_pool = Pool(X_train[current_features], y_train, cat_features=current_cat_features)
    val_pool = Pool(X_val[current_features], y_val, cat_features=current_cat_features)

    param_list = list(ParameterSampler(param_grid, n_iter=8, random_state=SEED))
    
    best_step_f1 = 0
    best_step_thr = 0.5
    best_step_model = None

    for i, params in enumerate(param_list):
        model = CatBoostClassifier(
            iterations=10000,
            task_type='GPU',
            eval_metric='Logloss',
            loss_function='Logloss',
            random_seed=SEED,
            early_stopping_rounds=50,
            auto_class_weights='Balanced',
            verbose=100,
            **params
        )
        
        model.fit(train_pool, eval_set=val_pool)
        
        probs = model.predict_proba(val_pool)[:, 1]
        y_true = val_pool.get_label()
        
        thresholds = np.linspace(0.01, 0.95, 100)
        model_max_f1 = 0
        model_best_thr = 0.5
        
        for t in thresholds:
            score = f1_score(y_true, probs > t)
            if score > model_max_f1:
                model_max_f1 = score
                model_best_thr = t
        
        if model_max_f1 > best_step_f1:
            best_step_f1 = model_max_f1
            best_step_thr = model_best_thr
            best_step_model = model

    print(f"Nejlepší F1 v iteraci {step}: {best_step_f1:.4f} (práh: {best_step_thr:.4f})")

    if best_step_f1 > best_overall_f1:
        best_overall_f1 = best_step_f1
        best_overall_thr = best_step_thr
        best_overall_model = best_step_model
        best_overall_features = current_features.copy()
        patience_counter = 0
    else:
        patience_counter += 1
        print(f"Skóre se nezlepšilo. Patience: {patience_counter}/{PATIENCE}")

    if patience_counter >= PATIENCE:
        print("Early stopping aktivován. Ukončuji iterativní ladění.")
        break

    fi = best_step_model.get_feature_importance(train_pool)
    df_fi = pd.DataFrame({'feature': current_features, 'importance': fi})
    df_fi = df_fi.sort_values(by='importance', ascending=False)
    
    drop_count = max(1, int(len(current_features) * DROP_RATIO))
    current_features = df_fi['feature'].head(len(current_features) - drop_count).tolist()
    print(f"Odstraněno {drop_count} nejméně důležitých příznaků.")
    
    step += 1

retained_ratio = (len(best_overall_features) / initial_feature_count) * 100

print("\n=== Iterativní proces dokončen ===")
print(f"Nejlepší celkové F1: {best_overall_f1:.4f} (práh: {best_overall_thr:.4f})")
print(f"Ponecháno příznaků: {len(best_overall_features)} ({retained_ratio:.2f} % z původních {initial_feature_count}).")
# Out:
# === Iterace 1 ===
# Počet příznaků: 222
# 0:	learn: 0.6884193	test: 0.6884254	best: 0.6884254 (0)	total: 576ms	remaining: 1h 36m 1s
# 100:	learn: 0.5966917	test: 0.5965461	best: 0.5965461 (100)	total: 52.8s	remaining: 1h 26m 13s
# 200:	learn: 0.5907095	test: 0.5909968	best: 0.5909968 (200)	total: 1m 42s	remaining: 1h 23m 12s
# 300:	learn: 0.5880368	test: 0.5886293	best: 0.5886293 (300)	total: 2m 32s	remaining: 1h 21m 54s
# 400:	learn: 0.5862648	test: 0.5871673	best: 0.5871673 (400)	total: 3m 22s	remaining: 1h 20m 55s
# 500:	learn: 0.5848562	test: 0.5860427	best: 0.5860427 (500)	total: 4m 11s	remaining: 1h 19m 37s
# 600:	learn: 0.5836508	test: 0.5851856	best: 0.5851856 (600)	total: 5m 1s	remaining: 1h 18m 29s
# 700:	learn: 0.5825383	test: 0.5843712	best: 0.5843712 (700)	total: 5m 50s	remaining: 1h 17m 26s
# 800:	learn: 0.5816444	test: 0.5838035	best: 0.5838035 (800)	total: 6m 38s	remaining: 1h 16m 20s
# 900:	learn: 0.5808828	test: 0.5833338	best: 0.5833338 (900)	total: 7m 27s	remaining: 1h 15m 18s
# 1000:	learn: 0.5801488	test: 0.5828796	best: 0.5828784 (999)	total: 8m 15s	remaining: 1h 14m 18s
# 1100:	learn: 0.5795051	test: 0.5824959	best: 0.5824959 (1100)	total: 9m 4s	remaining: 1h 13m 20s
# 1200:	learn: 0.5789195	test: 0.5821842	best: 0.5821842 (1200)	total: 9m 53s	remaining: 1h 12m 27s
# 1300:	learn: 0.5783326	test: 0.5818465	best: 0.5818465 (1300)	total: 10m 41s	remaining: 1h 11m 29s
# 1400:	learn: 0.5777749	test: 0.5815822	best: 0.5815822 (1400)	total: 11m 29s	remaining: 1h 10m 32s
# 1500:	learn: 0.5772826	test: 0.5813781	best: 0.5813781 (1500)	total: 12m 18s	remaining: 1h 9m 42s
# 1600:	learn: 0.5767918	test: 0.5811896	best: 0.5811896 (1600)	total: 13m 6s	remaining: 1h 8m 47s
# 1700:	learn: 0.5763152	test: 0.5809835	best: 0.5809835 (1700)	total: 13m 55s	remaining: 1h 7m 56s
# 1800:	learn: 0.5758469	test: 0.5807825	best: 0.5807825 (1800)	total: 14m 42s	remaining: 1h 6m 58s
# 1900:	learn: 0.5754095	test: 0.5806551	best: 0.5806551 (1900)	total: 15m 32s	remaining: 1h 6m 11s
# 2000:	learn: 0.5749772	test: 0.5805002	best: 0.5805002 (2000)	total: 16m 21s	remaining: 1h 5m 24s
# 2100:	learn: 0.5745290	test: 0.5803147	best: 0.5803147 (2100)	total: 17m 10s	remaining: 1h 4m 35s
# 2200:	learn: 0.5741298	test: 0.5801887	best: 0.5801887 (2200)	total: 17m 59s	remaining: 1h 3m 44s
# 2300:	learn: 0.5736970	test: 0.5800455	best: 0.5800455 (2300)	total: 18m 48s	remaining: 1h 2m 56s
# 2400:	learn: 0.5733437	test: 0.5799422	best: 0.5799422 (2400)	total: 19m 37s	remaining: 1h 2m 6s
# 2500:	learn: 0.5729538	test: 0.5798118	best: 0.5798118 (2500)	total: 20m 26s	remaining: 1h 1m 17s
# 2600:	learn: 0.5725837	test: 0.5796876	best: 0.5796876 (2600)	total: 21m 15s	remaining: 1h 28s
# 2700:	learn: 0.5722193	test: 0.5796052	best: 0.5796052 (2700)	total: 22m 5s	remaining: 59m 41s
# 2800:	learn: 0.5718677	test: 0.5795115	best: 0.5795115 (2799)	total: 22m 54s	remaining: 58m 51s
# 2900:	learn: 0.5715270	test: 0.5794093	best: 0.5794093 (2900)	total: 23m 43s	remaining: 58m 2s
# 3000:	learn: 0.5711769	test: 0.5793145	best: 0.5793138 (2998)	total: 24m 32s	remaining: 57m 13s
# 3100:	learn: 0.5708505	test: 0.5792349	best: 0.5792339 (3098)	total: 25m 20s	remaining: 56m 23s
# 3200:	learn: 0.5705021	test: 0.5791297	best: 0.5791297 (3200)	total: 26m 10s	remaining: 55m 34s
# 3300:	learn: 0.5701524	test: 0.5790442	best: 0.5790442 (3300)	total: 26m 59s	remaining: 54m 47s
# 3400:	learn: 0.5698364	test: 0.5789842	best: 0.5789842 (3400)	total: 27m 48s	remaining: 53m 57s
# 3500:	learn: 0.5695186	test: 0.5789345	best: 0.5789342 (3498)	total: 28m 37s	remaining: 53m 7s
# 3600:	learn: 0.5691800	test: 0.5788794	best: 0.5788794 (3600)	total: 29m 26s	remaining: 52m 18s
# 3700:	learn: 0.5688323	test: 0.5788003	best: 0.5788003 (3700)	total: 30m 15s	remaining: 51m 30s
# 3800:	learn: 0.5685164	test: 0.5787366	best: 0.5787347 (3797)	total: 31m 5s	remaining: 50m 42s
# 3900:	learn: 0.5682173	test: 0.5787022	best: 0.5787022 (3892)	total: 31m 55s	remaining: 49m 55s
# 4000:	learn: 0.5679021	test: 0.5786547	best: 0.5786545 (3999)	total: 32m 44s	remaining: 49m 5s
# 4100:	learn: 0.5675970	test: 0.5786071	best: 0.5786071 (4100)	total: 33m 34s	remaining: 48m 17s
# 4200:	learn: 0.5673090	test: 0.5785446	best: 0.5785426 (4198)	total: 34m 22s	remaining: 47m 27s
# bestTest = 0.578538377
# bestIteration = 4222
# Shrink model to first 4223 iterations.
# 0:	learn: 0.6853569	test: 0.6853674	best: 0.6853674 (0)	total: 573ms	remaining: 1h 35m 29s
# 100:	learn: 0.5919289	test: 0.5920339	best: 0.5920339 (100)	total: 53.2s	remaining: 1h 26m 53s
# 200:	learn: 0.5873544	test: 0.5880009	best: 0.5880009 (200)	total: 1m 43s	remaining: 1h 24m 12s
# 300:	learn: 0.5847329	test: 0.5859315	best: 0.5859315 (300)	total: 2m 33s	remaining: 1h 22m 10s
# 400:	learn: 0.5829996	test: 0.5847100	best: 0.5847100 (400)	total: 3m 21s	remaining: 1h 20m 32s
# 500:	learn: 0.5814987	test: 0.5837067	best: 0.5837067 (500)	total: 4m 11s	remaining: 1h 19m 26s
# 600:	learn: 0.5802166	test: 0.5829300	best: 0.5829300 (600)	total: 4m 59s	remaining: 1h 17m 57s
# 700:	learn: 0.5790645	test: 0.5823191	best: 0.5823191 (700)	total: 5m 48s	remaining: 1h 16m 59s
# 800:	learn: 0.5781754	test: 0.5818826	best: 0.5818826 (800)	total: 6m 36s	remaining: 1h 15m 47s
# 900:	learn: 0.5773070	test: 0.5814768	best: 0.5814768 (900)	total: 7m 23s	remaining: 1h 14m 38s
# 1000:	learn: 0.5765217	test: 0.5811413	best: 0.5811392 (999)	total: 8m 12s	remaining: 1h 13m 44s
# 1100:	learn: 0.5757422	test: 0.5808205	best: 0.5808205 (1100)	total: 9m	remaining: 1h 12m 48s
# 1200:	learn: 0.5750025	test: 0.5805334	best: 0.5805334 (1200)	total: 9m 48s	remaining: 1h 11m 50s
# 1300:	learn: 0.5743106	test: 0.5802915	best: 0.5802915 (1300)	total: 10m 36s	remaining: 1h 10m 57s
# 1400:	learn: 0.5736270	test: 0.5800836	best: 0.5800836 (1400)	total: 11m 26s	remaining: 1h 10m 11s
# 1500:	learn: 0.5730060	test: 0.5798801	best: 0.5798770 (1498)	total: 12m 14s	remaining: 1h 9m 17s
# 1600:	learn: 0.5723868	test: 0.5797173	best: 0.5797173 (1600)	total: 13m 3s	remaining: 1h 8m 28s
# 1700:	learn: 0.5717949	test: 0.5795377	best: 0.5795373 (1699)	total: 13m 51s	remaining: 1h 7m 38s
# 1800:	learn: 0.5712234	test: 0.5794343	best: 0.5794343 (1800)	total: 14m 40s	remaining: 1h 6m 49s
# 1900:	learn: 0.5706727	test: 0.5793391	best: 0.5793385 (1898)	total: 15m 30s	remaining: 1h 6m 2s
# 2000:	learn: 0.5701061	test: 0.5792606	best: 0.5792606 (2000)	total: 16m 18s	remaining: 1h 5m 12s
# 2100:	learn: 0.5695513	test: 0.5791851	best: 0.5791851 (2100)	total: 17m 8s	remaining: 1h 4m 26s
# 2200:	learn: 0.5689925	test: 0.5790927	best: 0.5790888 (2199)	total: 17m 57s	remaining: 1h 3m 38s
# 2300:	learn: 0.5684620	test: 0.5790041	best: 0.5790041 (2300)	total: 18m 47s	remaining: 1h 2m 53s
# 2400:	learn: 0.5679614	test: 0.5789219	best: 0.5789135 (2386)	total: 19m 36s	remaining: 1h 2m 2s
# 2500:	learn: 0.5674206	test: 0.5788358	best: 0.5788358 (2500)	total: 20m 25s	remaining: 1h 1m 15s
# 2600:	learn: 0.5669393	test: 0.5787448	best: 0.5787406 (2584)	total: 21m 14s	remaining: 1h 26s
# 2700:	learn: 0.5664289	test: 0.5786552	best: 0.5786538 (2699)	total: 22m 3s	remaining: 59m 37s
# 2800:	learn: 0.5659429	test: 0.5786097	best: 0.5786097 (2800)	total: 22m 53s	remaining: 58m 49s
# 2900:	learn: 0.5654646	test: 0.5785380	best: 0.5785375 (2898)	total: 23m 43s	remaining: 58m 2s
# 3000:	learn: 0.5650075	test: 0.5784606	best: 0.5784606 (3000)	total: 24m 32s	remaining: 57m 13s
# 3100:	learn: 0.5645244	test: 0.5784274	best: 0.5784220 (3092)	total: 25m 20s	remaining: 56m 23s
# 3200:	learn: 0.5640548	test: 0.5783748	best: 0.5783741 (3199)	total: 26m 11s	remaining: 55m 37s
# 3300:	learn: 0.5635989	test: 0.5783456	best: 0.5783435 (3291)	total: 27m 1s	remaining: 54m 49s
# 3400:	learn: 0.5631555	test: 0.5783263	best: 0.5783239 (3392)	total: 27m 51s	remaining: 54m 2s
# 3500:	learn: 0.5626826	test: 0.5783203	best: 0.5783007 (3463)	total: 28m 41s	remaining: 53m 15s
# bestTest = 0.5783007127
# bestIteration = 3463
# Shrink model to first 3464 iterations.
# 0:	learn: 0.6780205	test: 0.6780394	best: 0.6780394 (0)	total: 567ms	remaining: 1h 34m 25s
# 100:	learn: 0.5875244	test: 0.5882979	best: 0.5882979 (100)	total: 52.2s	remaining: 1h 25m 19s
# 200:	learn: 0.5831909	test: 0.5850426	best: 0.5850426 (200)	total: 1m 41s	remaining: 1h 22m 23s
# 300:	learn: 0.5805311	test: 0.5833704	best: 0.5833704 (300)	total: 2m 29s	remaining: 1h 20m 25s
# 400:	learn: 0.5785577	test: 0.5822975	best: 0.5822975 (400)	total: 3m 18s	remaining: 1h 19m 1s
# 500:	learn: 0.5768330	test: 0.5814561	best: 0.5814561 (500)	total: 4m 7s	remaining: 1h 18m 4s
# 600:	learn: 0.5754647	test: 0.5808436	best: 0.5808436 (600)	total: 4m 55s	remaining: 1h 17m 1s
# 700:	learn: 0.5740651	test: 0.5803480	best: 0.5803469 (695)	total: 5m 43s	remaining: 1h 16m
# 800:	learn: 0.5729045	test: 0.5800482	best: 0.5800464 (799)	total: 6m 31s	remaining: 1h 15m
# 900:	learn: 0.5717292	test: 0.5796923	best: 0.5796923 (900)	total: 7m 21s	remaining: 1h 14m 14s
# 1000:	learn: 0.5706304	test: 0.5794427	best: 0.5794400 (996)	total: 8m 10s	remaining: 1h 13m 26s
# 1100:	learn: 0.5696502	test: 0.5793056	best: 0.5793056 (1100)	total: 8m 58s	remaining: 1h 12m 36s
# 1200:	learn: 0.5687170	test: 0.5792165	best: 0.5792142 (1194)	total: 9m 46s	remaining: 1h 11m 39s
# 1300:	learn: 0.5677792	test: 0.5790162	best: 0.5790105 (1298)	total: 10m 35s	remaining: 1h 10m 48s
# 1400:	learn: 0.5668137	test: 0.5788814	best: 0.5788814 (1400)	total: 11m 24s	remaining: 1h 10m 1s
# 1500:	learn: 0.5659228	test: 0.5787491	best: 0.5787442 (1498)	total: 12m 14s	remaining: 1h 9m 17s
# bestTest = 0.578738578
# bestIteration = 1504
# Shrink model to first 1505 iterations.
# 0:	learn: 0.6780204	test: 0.6780389	best: 0.6780389 (0)	total: 564ms	remaining: 1h 33m 59s
# 100:	learn: 0.5875223	test: 0.5883003	best: 0.5883003 (100)	total: 52.3s	remaining: 1h 25m 28s
# 200:	learn: 0.5831982	test: 0.5849855	best: 0.5849855 (200)	total: 1m 41s	remaining: 1h 22m 32s
# 300:	learn: 0.5804459	test: 0.5833295	best: 0.5833295 (300)	total: 2m 30s	remaining: 1h 20m 45s
# 400:	learn: 0.5784966	test: 0.5823386	best: 0.5823386 (400)	total: 3m 18s	remaining: 1h 19m 11s
# 500:	learn: 0.5768414	test: 0.5816485	best: 0.5816485 (500)	total: 4m 7s	remaining: 1h 18m 6s
# 600:	learn: 0.5754156	test: 0.5811191	best: 0.5811190 (598)	total: 4m 56s	remaining: 1h 17m 10s
# 700:	learn: 0.5740242	test: 0.5806287	best: 0.5806287 (700)	total: 5m 44s	remaining: 1h 16m 13s
# 800:	learn: 0.5728500	test: 0.5802922	best: 0.5802907 (799)	total: 6m 34s	remaining: 1h 15m 31s
# 900:	learn: 0.5716807	test: 0.5800594	best: 0.5800552 (898)	total: 7m 23s	remaining: 1h 14m 41s
# 1000:	learn: 0.5705509	test: 0.5797538	best: 0.5797459 (996)	total: 8m 12s	remaining: 1h 13m 51s
# 1100:	learn: 0.5694990	test: 0.5795248	best: 0.5795248 (1100)	total: 9m 1s	remaining: 1h 12m 55s
# 1200:	learn: 0.5685117	test: 0.5793401	best: 0.5793400 (1199)	total: 9m 50s	remaining: 1h 12m 4s
# 1300:	learn: 0.5675378	test: 0.5792012	best: 0.5791985 (1294)	total: 10m 39s	remaining: 1h 11m 18s
# 1400:	learn: 0.5666062	test: 0.5790462	best: 0.5790451 (1399)	total: 11m 28s	remaining: 1h 10m 26s
# 1500:	learn: 0.5656771	test: 0.5789167	best: 0.5789167 (1500)	total: 12m 19s	remaining: 1h 9m 44s
# 1600:	learn: 0.5647798	test: 0.5788399	best: 0.5788385 (1597)	total: 13m 8s	remaining: 1h 8m 56s
# 1700:	learn: 0.5638772	test: 0.5787538	best: 0.5787499 (1698)	total: 13m 58s	remaining: 1h 8m 10s
# bestTest = 0.5787471014
# bestIteration = 1718
# Shrink model to first 1719 iterations.
# 0:	learn: 0.6884191	test: 0.6884253	best: 0.6884253 (0)	total: 572ms	remaining: 1h 35m 22s
# 100:	learn: 0.5966940	test: 0.5965465	best: 0.5965465 (100)	total: 53.3s	remaining: 1h 27m 5s
# 200:	learn: 0.5906772	test: 0.5909531	best: 0.5909531 (200)	total: 1m 44s	remaining: 1h 24m 45s
# 300:	learn: 0.5880333	test: 0.5886245	best: 0.5886245 (300)	total: 2m 36s	remaining: 1h 24m 3s
# 400:	learn: 0.5861747	test: 0.5871286	best: 0.5871286 (400)	total: 3m 29s	remaining: 1h 23m 31s
# 500:	learn: 0.5847639	test: 0.5860151	best: 0.5860151 (500)	total: 4m 22s	remaining: 1h 22m 52s
# 600:	learn: 0.5836057	test: 0.5851332	best: 0.5851332 (600)	total: 5m 13s	remaining: 1h 21m 38s
# 700:	learn: 0.5825356	test: 0.5843964	best: 0.5843964 (700)	total: 6m 3s	remaining: 1h 20m 21s
# 800:	learn: 0.5816762	test: 0.5838707	best: 0.5838707 (800)	total: 6m 53s	remaining: 1h 19m 7s
# 900:	learn: 0.5809071	test: 0.5833834	best: 0.5833834 (900)	total: 7m 43s	remaining: 1h 17m 59s
# 1000:	learn: 0.5801836	test: 0.5829174	best: 0.5829170 (999)	total: 8m 33s	remaining: 1h 16m 56s
# 1100:	learn: 0.5795334	test: 0.5825047	best: 0.5825047 (1100)	total: 9m 24s	remaining: 1h 15m 59s
# 1200:	learn: 0.5789682	test: 0.5822110	best: 0.5822110 (1200)	total: 10m 13s	remaining: 1h 14m 51s
# 1300:	learn: 0.5783720	test: 0.5818811	best: 0.5818811 (1300)	total: 11m 1s	remaining: 1h 13m 44s
# 1400:	learn: 0.5778390	test: 0.5816293	best: 0.5816293 (1400)	total: 11m 50s	remaining: 1h 12m 40s
# 1500:	learn: 0.5773149	test: 0.5813703	best: 0.5813664 (1497)	total: 12m 39s	remaining: 1h 11m 39s
# 1600:	learn: 0.5768491	test: 0.5812007	best: 0.5812007 (1600)	total: 13m 27s	remaining: 1h 10m 34s
# 1700:	learn: 0.5763821	test: 0.5809944	best: 0.5809944 (1700)	total: 14m 16s	remaining: 1h 9m 37s
# 1800:	learn: 0.5759155	test: 0.5808143	best: 0.5808143 (1800)	total: 15m 4s	remaining: 1h 8m 37s
# 1900:	learn: 0.5754774	test: 0.5806682	best: 0.5806682 (1900)	total: 15m 53s	remaining: 1h 7m 44s
# 2000:	learn: 0.5750544	test: 0.5804946	best: 0.5804946 (2000)	total: 16m 43s	remaining: 1h 6m 50s
# 2100:	learn: 0.5746334	test: 0.5803360	best: 0.5803357 (2098)	total: 17m 32s	remaining: 1h 5m 58s
# 2200:	learn: 0.5742394	test: 0.5801915	best: 0.5801915 (2200)	total: 18m 21s	remaining: 1h 5m 2s
# 2300:	learn: 0.5738117	test: 0.5800529	best: 0.5800529 (2300)	total: 19m 11s	remaining: 1h 4m 12s
# 2400:	learn: 0.5734476	test: 0.5799208	best: 0.5799208 (2400)	total: 20m	remaining: 1h 3m 18s
# 2500:	learn: 0.5730704	test: 0.5798329	best: 0.5798329 (2500)	total: 20m 49s	remaining: 1h 2m 25s
# 2600:	learn: 0.5726992	test: 0.5797203	best: 0.5797203 (2600)	total: 21m 38s	remaining: 1h 1m 33s
# 2700:	learn: 0.5723294	test: 0.5796084	best: 0.5796083 (2699)	total: 22m 27s	remaining: 1h 41s
# 2800:	learn: 0.5719738	test: 0.5794964	best: 0.5794964 (2800)	total: 23m 17s	remaining: 59m 51s
# 2900:	learn: 0.5716403	test: 0.5794111	best: 0.5794111 (2900)	total: 24m 6s	remaining: 59m
# 3000:	learn: 0.5713146	test: 0.5793133	best: 0.5793131 (2999)	total: 24m 55s	remaining: 58m 7s
# 3100:	learn: 0.5709684	test: 0.5792029	best: 0.5792029 (3098)	total: 25m 43s	remaining: 57m 14s
# 3200:	learn: 0.5706474	test: 0.5791092	best: 0.5791092 (3200)	total: 26m 33s	remaining: 56m 24s
# 3300:	learn: 0.5703220	test: 0.5790310	best: 0.5790310 (3300)	total: 27m 23s	remaining: 55m 34s
# 3400:	learn: 0.5700173	test: 0.5789720	best: 0.5789720 (3400)	total: 28m 12s	remaining: 54m 43s
# 3500:	learn: 0.5697023	test: 0.5788820	best: 0.5788814 (3498)	total: 29m	remaining: 53m 50s
# 3600:	learn: 0.5693796	test: 0.5788394	best: 0.5788394 (3600)	total: 29m 48s	remaining: 52m 58s
# 3700:	learn: 0.5690333	test: 0.5787661	best: 0.5787649 (3699)	total: 30m 39s	remaining: 52m 10s
# 3800:	learn: 0.5687169	test: 0.5786972	best: 0.5786972 (3800)	total: 31m 29s	remaining: 51m 21s
# 3900:	learn: 0.5684137	test: 0.5786510	best: 0.5786510 (3900)	total: 32m 19s	remaining: 50m 31s
# 4000:	learn: 0.5681153	test: 0.5786072	best: 0.5786070 (3999)	total: 33m 8s	remaining: 49m 41s
# 4100:	learn: 0.5678119	test: 0.5785719	best: 0.5785719 (4100)	total: 33m 57s	remaining: 48m 50s
# 4200:	learn: 0.5675358	test: 0.5785158	best: 0.5785158 (4200)	total: 34m 45s	remaining: 47m 59s
# 4300:	learn: 0.5672469	test: 0.5784811	best: 0.5784798 (4295)	total: 35m 35s	remaining: 47m 9s
# 4400:	learn: 0.5669432	test: 0.5784387	best: 0.5784369 (4398)	total: 36m 24s	remaining: 46m 19s
# 4500:	learn: 0.5666465	test: 0.5783811	best: 0.5783808 (4499)	total: 37m 13s	remaining: 45m 28s
# 4600:	learn: 0.5663493	test: 0.5783481	best: 0.5783474 (4596)	total: 38m 2s	remaining: 44m 38s
# 4700:	learn: 0.5660650	test: 0.5782856	best: 0.5782847 (4696)	total: 38m 52s	remaining: 43m 49s
# 4800:	learn: 0.5657760	test: 0.5782437	best: 0.5782408 (4794)	total: 39m 42s	remaining: 43m
# 4900:	learn: 0.5654817	test: 0.5782020	best: 0.5781988 (4898)	total: 40m 32s	remaining: 42m 11s
# 5000:	learn: 0.5651966	test: 0.5781646	best: 0.5781646 (5000)	total: 41m 21s	remaining: 41m 20s
# 5100:	learn: 0.5649112	test: 0.5781324	best: 0.5781302 (5096)	total: 42m 11s	remaining: 40m 31s
# 5200:	learn: 0.5646402	test: 0.5780942	best: 0.5780940 (5183)	total: 43m 2s	remaining: 39m 42s
# 5300:	learn: 0.5643603	test: 0.5780605	best: 0.5780604 (5299)	total: 43m 52s	remaining: 38m 53s
# 5400:	learn: 0.5641042	test: 0.5780510	best: 0.5780473 (5394)	total: 44m 41s	remaining: 38m 3s
# 5500:	learn: 0.5638165	test: 0.5780050	best: 0.5780046 (5499)	total: 45m 31s	remaining: 37m 13s
# 5600:	learn: 0.5635472	test: 0.5779758	best: 0.5779748 (5598)	total: 46m 20s	remaining: 36m 23s
# 5700:	learn: 0.5632686	test: 0.5779441	best: 0.5779409 (5672)	total: 47m 9s	remaining: 35m 33s
# 5800:	learn: 0.5629973	test: 0.5779327	best: 0.5779288 (5798)	total: 47m 59s	remaining: 34m 43s
# bestTest = 0.5779266739
# bestIteration = 5809
# Shrink model to first 5810 iterations.
# 0:	learn: 0.6848836	test: 0.6849231	best: 0.6849231 (0)	total: 814ms	remaining: 2h 15m 43s
# 100:	learn: 0.5886524	test: 0.5895604	best: 0.5895604 (100)	total: 1m 9s	remaining: 1h 53m 16s
# 200:	learn: 0.5833401	test: 0.5857615	best: 0.5857615 (200)	total: 2m 16s	remaining: 1h 50m 56s
# 300:	learn: 0.5798944	test: 0.5838420	best: 0.5838420 (300)	total: 3m 21s	remaining: 1h 48m 14s
# 400:	learn: 0.5770887	test: 0.5825299	best: 0.5825299 (400)	total: 4m 27s	remaining: 1h 46m 34s
# 500:	learn: 0.5748046	test: 0.5816069	best: 0.5816069 (500)	total: 5m 32s	remaining: 1h 44m 58s
# 600:	learn: 0.5726745	test: 0.5809122	best: 0.5809122 (600)	total: 6m 36s	remaining: 1h 43m 21s
# 700:	learn: 0.5706195	test: 0.5804620	best: 0.5804620 (700)	total: 7m 41s	remaining: 1h 42m 7s
# 800:	learn: 0.5687400	test: 0.5800351	best: 0.5800326 (799)	total: 8m 47s	remaining: 1h 40m 55s
# 900:	learn: 0.5669752	test: 0.5796935	best: 0.5796921 (898)	total: 9m 52s	remaining: 1h 39m 45s
# 1000:	learn: 0.5652109	test: 0.5794280	best: 0.5794280 (1000)	total: 10m 58s	remaining: 1h 38m 43s
# 1100:	learn: 0.5635268	test: 0.5792075	best: 0.5792070 (1099)	total: 12m 5s	remaining: 1h 37m 42s
# 1200:	learn: 0.5619623	test: 0.5790313	best: 0.5790226 (1194)	total: 13m 10s	remaining: 1h 36m 33s
# 1300:	learn: 0.5604129	test: 0.5789197	best: 0.5789197 (1300)	total: 14m 17s	remaining: 1h 35m 33s
# 1400:	learn: 0.5589011	test: 0.5788223	best: 0.5788223 (1400)	total: 15m 22s	remaining: 1h 34m 25s
# bestTest = 0.578816478
# bestIteration = 1402
# Shrink model to first 1403 iterations.
# 0:	learn: 0.6848834	test: 0.6849232	best: 0.6849232 (0)	total: 816ms	remaining: 2h 15m 54s
# 100:	learn: 0.5886700	test: 0.5895603	best: 0.5895603 (100)	total: 1m 9s	remaining: 1h 53m 42s
# 200:	learn: 0.5832472	test: 0.5856110	best: 0.5856110 (200)	total: 2m 16s	remaining: 1h 50m 38s
# 300:	learn: 0.5799016	test: 0.5837256	best: 0.5837256 (300)	total: 3m 20s	remaining: 1h 47m 47s
# 400:	learn: 0.5773057	test: 0.5826570	best: 0.5826570 (400)	total: 4m 26s	remaining: 1h 46m 28s
# 500:	learn: 0.5748702	test: 0.5816228	best: 0.5816228 (500)	total: 5m 32s	remaining: 1h 45m 10s
# 600:	learn: 0.5727922	test: 0.5810096	best: 0.5810093 (598)	total: 6m 37s	remaining: 1h 43m 43s
# 700:	learn: 0.5707648	test: 0.5805238	best: 0.5805238 (700)	total: 7m 45s	remaining: 1h 42m 50s
# 800:	learn: 0.5689732	test: 0.5801971	best: 0.5801955 (799)	total: 8m 49s	remaining: 1h 41m 22s
# 900:	learn: 0.5672134	test: 0.5798669	best: 0.5798669 (900)	total: 9m 55s	remaining: 1h 40m 12s
# 1000:	learn: 0.5654801	test: 0.5796912	best: 0.5796912 (1000)	total: 11m 1s	remaining: 1h 39m 4s
# 1100:	learn: 0.5638180	test: 0.5795001	best: 0.5795001 (1100)	total: 12m 6s	remaining: 1h 37m 56s
# 1200:	learn: 0.5622955	test: 0.5793455	best: 0.5793434 (1199)	total: 13m 12s	remaining: 1h 36m 48s
# 1300:	learn: 0.5607463	test: 0.5791087	best: 0.5791087 (1300)	total: 14m 18s	remaining: 1h 35m 39s
# 1400:	learn: 0.5591969	test: 0.5790008	best: 0.5789891 (1381)	total: 15m 23s	remaining: 1h 34m 27s
# bestTest = 0.5789890604
# bestIteration = 1381
# Shrink model to first 1382 iterations.
# 0:	learn: 0.6881298	test: 0.6881546	best: 0.6881546 (0)	total: 814ms	remaining: 2h 15m 37s
# 100:	learn: 0.5930654	test: 0.5934462	best: 0.5934462 (100)	total: 1m 8s	remaining: 1h 52m 26s
# 200:	learn: 0.5872615	test: 0.5885758	best: 0.5885758 (200)	total: 2m 17s	remaining: 1h 51m 40s
# 300:	learn: 0.5841807	test: 0.5863559	best: 0.5863559 (300)	total: 3m 23s	remaining: 1h 49m 28s
# 400:	learn: 0.5819728	test: 0.5850183	best: 0.5850183 (400)	total: 4m 29s	remaining: 1h 47m 29s
# 500:	learn: 0.5799760	test: 0.5838810	best: 0.5838810 (500)	total: 5m 35s	remaining: 1h 45m 54s
# 600:	learn: 0.5782193	test: 0.5829606	best: 0.5829606 (600)	total: 6m 41s	remaining: 1h 44m 36s
# 700:	learn: 0.5766307	test: 0.5823322	best: 0.5823322 (700)	total: 7m 48s	remaining: 1h 43m 35s
# 800:	learn: 0.5752335	test: 0.5818357	best: 0.5818357 (800)	total: 8m 54s	remaining: 1h 42m 15s
# 900:	learn: 0.5739028	test: 0.5813376	best: 0.5813376 (900)	total: 9m 57s	remaining: 1h 40m 38s
# 1000:	learn: 0.5725752	test: 0.5809013	best: 0.5808994 (999)	total: 11m 4s	remaining: 1h 39m 30s
# 1100:	learn: 0.5714111	test: 0.5806016	best: 0.5806016 (1100)	total: 12m 9s	remaining: 1h 38m 17s
# 1200:	learn: 0.5703503	test: 0.5803270	best: 0.5803264 (1198)	total: 13m 14s	remaining: 1h 36m 57s
# 1300:	learn: 0.5692851	test: 0.5800594	best: 0.5800594 (1300)	total: 14m 18s	remaining: 1h 35m 36s
# 1400:	learn: 0.5682028	test: 0.5798437	best: 0.5798421 (1398)	total: 15m 22s	remaining: 1h 34m 24s
# 1500:	learn: 0.5671576	test: 0.5796339	best: 0.5796339 (1500)	total: 16m 28s	remaining: 1h 33m 15s
# 1600:	learn: 0.5661959	test: 0.5794629	best: 0.5794629 (1600)	total: 17m 31s	remaining: 1h 31m 56s
# 1700:	learn: 0.5651827	test: 0.5792964	best: 0.5792964 (1700)	total: 18m 35s	remaining: 1h 30m 40s
# 1800:	learn: 0.5642214	test: 0.5791713	best: 0.5791713 (1800)	total: 19m 40s	remaining: 1h 29m 32s
# 1900:	learn: 0.5632540	test: 0.5790588	best: 0.5790504 (1885)	total: 20m 46s	remaining: 1h 28m 32s
# 2000:	learn: 0.5623236	test: 0.5789132	best: 0.5789132 (2000)	total: 21m 52s	remaining: 1h 27m 25s
# 2100:	learn: 0.5613656	test: 0.5788002	best: 0.5788002 (2100)	total: 22m 57s	remaining: 1h 26m 20s
# 2200:	learn: 0.5604239	test: 0.5787517	best: 0.5787379 (2190)	total: 24m 4s	remaining: 1h 25m 18s
# 2300:	learn: 0.5594654	test: 0.5786374	best: 0.5786374 (2300)	total: 25m 10s	remaining: 1h 24m 12s
# 2400:	learn: 0.5585858	test: 0.5786070	best: 0.5785850 (2384)	total: 26m 15s	remaining: 1h 23m 4s
# bestTest = 0.5785849584
# bestIteration = 2384
# Shrink model to first 2385 iterations.
# Nejlepší F1 v iteraci 1: 0.1515 (práh: 0.7411)
# Odstraněno 22 nejméně důležitých příznaků.
#
# === Iterace 2 ===
# Počet příznaků: 200
# 0:	learn: 0.6884193	test: 0.6884251	best: 0.6884251 (0)	total: 566ms	remaining: 1h 34m 17s
# 100:	learn: 0.5967293	test: 0.5965945	best: 0.5965945 (100)	total: 52.9s	remaining: 1h 26m 27s
# 200:	learn: 0.5907757	test: 0.5910914	best: 0.5910914 (200)	total: 1m 42s	remaining: 1h 23m 24s
# 300:	learn: 0.5880947	test: 0.5887499	best: 0.5887499 (300)	total: 2m 32s	remaining: 1h 21m 52s
# 400:	learn: 0.5863373	test: 0.5872993	best: 0.5872993 (400)	total: 3m 22s	remaining: 1h 20m 50s
# 500:	learn: 0.5848636	test: 0.5861216	best: 0.5861216 (500)	total: 4m 12s	remaining: 1h 19m 50s
# 600:	learn: 0.5836800	test: 0.5852511	best: 0.5852511 (600)	total: 5m 2s	remaining: 1h 18m 47s
# 700:	learn: 0.5825804	test: 0.5844372	best: 0.5844372 (700)	total: 5m 50s	remaining: 1h 17m 29s
# 800:	learn: 0.5816899	test: 0.5838654	best: 0.5838654 (800)	total: 6m 39s	remaining: 1h 16m 27s
# 900:	learn: 0.5809391	test: 0.5833959	best: 0.5833959 (900)	total: 7m 27s	remaining: 1h 15m 23s
# 1000:	learn: 0.5801858	test: 0.5829320	best: 0.5829308 (999)	total: 8m 16s	remaining: 1h 14m 21s
# 1100:	learn: 0.5795532	test: 0.5825701	best: 0.5825701 (1100)	total: 9m 4s	remaining: 1h 13m 23s
# 1200:	learn: 0.5790015	test: 0.5823054	best: 0.5823054 (1200)	total: 9m 53s	remaining: 1h 12m 25s
# 1300:	learn: 0.5784129	test: 0.5819697	best: 0.5819697 (1300)	total: 10m 42s	remaining: 1h 11m 33s
# 1400:	learn: 0.5778514	test: 0.5816833	best: 0.5816833 (1400)	total: 11m 30s	remaining: 1h 10m 38s
# 1500:	learn: 0.5773490	test: 0.5814523	best: 0.5814523 (1500)	total: 12m 18s	remaining: 1h 9m 41s
# 1600:	learn: 0.5768379	test: 0.5812364	best: 0.5812364 (1600)	total: 13m 6s	remaining: 1h 8m 46s
# 1700:	learn: 0.5763696	test: 0.5810503	best: 0.5810503 (1700)	total: 13m 54s	remaining: 1h 7m 51s
# 1800:	learn: 0.5759173	test: 0.5809004	best: 0.5809004 (1800)	total: 14m 42s	remaining: 1h 6m 58s
# 1900:	learn: 0.5754783	test: 0.5807241	best: 0.5807241 (1900)	total: 15m 31s	remaining: 1h 6m 10s
# 2000:	learn: 0.5750240	test: 0.5805352	best: 0.5805352 (2000)	total: 16m 20s	remaining: 1h 5m 21s
# 2100:	learn: 0.5745797	test: 0.5803689	best: 0.5803689 (2100)	total: 17m 9s	remaining: 1h 4m 31s
# 2200:	learn: 0.5741845	test: 0.5802369	best: 0.5802360 (2198)	total: 17m 58s	remaining: 1h 3m 40s
# 2300:	learn: 0.5737581	test: 0.5800890	best: 0.5800890 (2300)	total: 18m 47s	remaining: 1h 2m 52s
# 2400:	learn: 0.5733837	test: 0.5799838	best: 0.5799834 (2398)	total: 19m 35s	remaining: 1h 2m
# 2500:	learn: 0.5729998	test: 0.5798701	best: 0.5798699 (2499)	total: 20m 24s	remaining: 1h 1m 12s
# 2600:	learn: 0.5726213	test: 0.5797529	best: 0.5797529 (2600)	total: 21m 14s	remaining: 1h 25s
# 2700:	learn: 0.5722353	test: 0.5796405	best: 0.5796405 (2700)	total: 22m 3s	remaining: 59m 36s
# 2800:	learn: 0.5718872	test: 0.5795654	best: 0.5795654 (2800)	total: 22m 52s	remaining: 58m 48s
# 2900:	learn: 0.5715306	test: 0.5794682	best: 0.5794682 (2900)	total: 23m 41s	remaining: 57m 58s
# 3000:	learn: 0.5711794	test: 0.5793940	best: 0.5793939 (2998)	total: 24m 30s	remaining: 57m 9s
# 3100:	learn: 0.5708431	test: 0.5792943	best: 0.5792927 (3098)	total: 25m 18s	remaining: 56m 18s
# 3200:	learn: 0.5705045	test: 0.5791968	best: 0.5791968 (3200)	total: 26m 7s	remaining: 55m 28s
# 3300:	learn: 0.5701727	test: 0.5791246	best: 0.5791246 (3300)	total: 26m 56s	remaining: 54m 39s
# 3400:	learn: 0.5698463	test: 0.5790733	best: 0.5790657 (3391)	total: 27m 45s	remaining: 53m 51s
# 3500:	learn: 0.5695357	test: 0.5790133	best: 0.5790123 (3498)	total: 28m 33s	remaining: 53m 1s
# 3600:	learn: 0.5691994	test: 0.5789511	best: 0.5789496 (3599)	total: 29m 22s	remaining: 52m 12s
# 3700:	learn: 0.5688593	test: 0.5788877	best: 0.5788849 (3695)	total: 30m 13s	remaining: 51m 26s
# 3800:	learn: 0.5685315	test: 0.5787996	best: 0.5787980 (3798)	total: 31m 2s	remaining: 50m 38s
# 3900:	learn: 0.5682326	test: 0.5787573	best: 0.5787573 (3900)	total: 31m 52s	remaining: 49m 49s
# 4000:	learn: 0.5679305	test: 0.5787141	best: 0.5787141 (4000)	total: 32m 40s	remaining: 48m 59s
# bestTest = 0.5787012468
# bestIteration = 4015
# Shrink model to first 4016 iterations.
# 0:	learn: 0.6853572	test: 0.6853677	best: 0.6853677 (0)	total: 586ms	remaining: 1h 37m 35s
# 100:	learn: 0.5920832	test: 0.5923281	best: 0.5923281 (100)	total: 53.1s	remaining: 1h 26m 43s
# 200:	learn: 0.5874340	test: 0.5881868	best: 0.5881868 (200)	total: 1m 43s	remaining: 1h 24m 16s
# 300:	learn: 0.5848674	test: 0.5861722	best: 0.5861722 (300)	total: 2m 33s	remaining: 1h 22m 39s
# 400:	learn: 0.5830574	test: 0.5848919	best: 0.5848919 (400)	total: 3m 22s	remaining: 1h 20m 35s
# 500:	learn: 0.5815988	test: 0.5839575	best: 0.5839575 (500)	total: 4m 10s	remaining: 1h 19m 18s
# 600:	learn: 0.5803515	test: 0.5831869	best: 0.5831869 (600)	total: 4m 59s	remaining: 1h 17m 58s
# 700:	learn: 0.5792101	test: 0.5825532	best: 0.5825522 (699)	total: 5m 47s	remaining: 1h 16m 54s
# 800:	learn: 0.5783047	test: 0.5820869	best: 0.5820869 (800)	total: 6m 35s	remaining: 1h 15m 45s
# 900:	learn: 0.5774278	test: 0.5816986	best: 0.5816986 (900)	total: 7m 24s	remaining: 1h 14m 47s
# 1000:	learn: 0.5766568	test: 0.5813625	best: 0.5813625 (1000)	total: 8m 12s	remaining: 1h 13m 44s
# 1100:	learn: 0.5759259	test: 0.5810860	best: 0.5810846 (1099)	total: 9m	remaining: 1h 12m 49s
# 1200:	learn: 0.5751972	test: 0.5807789	best: 0.5807789 (1200)	total: 9m 49s	remaining: 1h 12m
# 1300:	learn: 0.5744898	test: 0.5805304	best: 0.5805304 (1300)	total: 10m 38s	remaining: 1h 11m 6s
# 1400:	learn: 0.5738155	test: 0.5803198	best: 0.5803198 (1400)	total: 11m 26s	remaining: 1h 10m 13s
# 1500:	learn: 0.5731557	test: 0.5801211	best: 0.5801211 (1500)	total: 12m 15s	remaining: 1h 9m 22s
# 1600:	learn: 0.5725372	test: 0.5799313	best: 0.5799313 (1600)	total: 13m 2s	remaining: 1h 8m 26s
# 1700:	learn: 0.5719775	test: 0.5797685	best: 0.5797681 (1699)	total: 13m 50s	remaining: 1h 7m 32s
# 1800:	learn: 0.5714107	test: 0.5796713	best: 0.5796709 (1799)	total: 14m 39s	remaining: 1h 6m 43s
# 1900:	learn: 0.5708675	test: 0.5795681	best: 0.5795681 (1900)	total: 15m 28s	remaining: 1h 5m 56s
# 2000:	learn: 0.5702957	test: 0.5794360	best: 0.5794360 (2000)	total: 16m 18s	remaining: 1h 5m 11s
# 2100:	learn: 0.5697587	test: 0.5793297	best: 0.5793297 (2100)	total: 17m 6s	remaining: 1h 4m 19s
# 2200:	learn: 0.5692093	test: 0.5792268	best: 0.5792234 (2199)	total: 17m 57s	remaining: 1h 3m 36s
# 2300:	learn: 0.5686636	test: 0.5791183	best: 0.5791183 (2300)	total: 18m 46s	remaining: 1h 2m 48s
# 2400:	learn: 0.5681425	test: 0.5790603	best: 0.5790584 (2399)	total: 19m 35s	remaining: 1h 1m 59s
# 2500:	learn: 0.5675957	test: 0.5789842	best: 0.5789842 (2500)	total: 20m 25s	remaining: 1h 1m 13s
# 2600:	learn: 0.5671023	test: 0.5789056	best: 0.5789056 (2600)	total: 21m 14s	remaining: 1h 24s
# 2700:	learn: 0.5665904	test: 0.5788140	best: 0.5788140 (2700)	total: 22m 3s	remaining: 59m 37s
# 2800:	learn: 0.5661054	test: 0.5788144	best: 0.5788014 (2757)	total: 22m 52s	remaining: 58m 47s
# bestTest = 0.5788014133
# bestIteration = 2757
# Shrink model to first 2758 iterations.
# 0:	learn: 0.6780207	test: 0.6780393	best: 0.6780393 (0)	total: 563ms	remaining: 1h 33m 52s
# 100:	learn: 0.5875950	test: 0.5880668	best: 0.5880668 (100)	total: 52.5s	remaining: 1h 25m 43s
# 200:	learn: 0.5831294	test: 0.5847759	best: 0.5847759 (200)	total: 1m 41s	remaining: 1h 22m 5s
# 300:	learn: 0.5804267	test: 0.5831188	best: 0.5831188 (300)	total: 2m 30s	remaining: 1h 20m 39s
# 400:	learn: 0.5785702	test: 0.5821839	best: 0.5821839 (400)	total: 3m 19s	remaining: 1h 19m 36s
# 500:	learn: 0.5769259	test: 0.5812986	best: 0.5812986 (500)	total: 4m 7s	remaining: 1h 18m 21s
# 600:	learn: 0.5755562	test: 0.5807777	best: 0.5807736 (598)	total: 4m 56s	remaining: 1h 17m 24s
# 700:	learn: 0.5741577	test: 0.5802542	best: 0.5802396 (695)	total: 5m 45s	remaining: 1h 16m 23s
# 800:	learn: 0.5729692	test: 0.5799212	best: 0.5799212 (800)	total: 6m 33s	remaining: 1h 15m 23s
# 900:	learn: 0.5718384	test: 0.5796363	best: 0.5796363 (900)	total: 7m 22s	remaining: 1h 14m 29s
# 1000:	learn: 0.5707098	test: 0.5793507	best: 0.5793507 (1000)	total: 8m 12s	remaining: 1h 13m 44s
# 1100:	learn: 0.5696315	test: 0.5791741	best: 0.5791741 (1100)	total: 9m 1s	remaining: 1h 12m 53s
# 1200:	learn: 0.5686737	test: 0.5790798	best: 0.5790664 (1193)	total: 9m 49s	remaining: 1h 12m 2s
# 1300:	learn: 0.5676878	test: 0.5789526	best: 0.5789420 (1297)	total: 10m 38s	remaining: 1h 11m 10s
# 1400:	learn: 0.5667654	test: 0.5788631	best: 0.5788631 (1400)	total: 11m 28s	remaining: 1h 10m 23s
# 1500:	learn: 0.5658621	test: 0.5787558	best: 0.5787548 (1496)	total: 12m 18s	remaining: 1h 9m 40s
# 1600:	learn: 0.5649499	test: 0.5786436	best: 0.5786323 (1587)	total: 13m 9s	remaining: 1h 9m
# bestTest = 0.5786322666
# bestIteration = 1587
# Shrink model to first 1588 iterations.
# 0:	learn: 0.6780204	test: 0.6780389	best: 0.6780389 (0)	total: 589ms	remaining: 1h 38m 5s
# 100:	learn: 0.5875910	test: 0.5880656	best: 0.5880656 (100)	total: 52.3s	remaining: 1h 25m 28s
# 200:	learn: 0.5831261	test: 0.5847832	best: 0.5847832 (200)	total: 1m 41s	remaining: 1h 22m 6s
# 300:	learn: 0.5805546	test: 0.5832153	best: 0.5832153 (300)	total: 2m 30s	remaining: 1h 20m 46s
# 400:	learn: 0.5786704	test: 0.5821892	best: 0.5821892 (400)	total: 3m 20s	remaining: 1h 19m 50s
# 500:	learn: 0.5769647	test: 0.5813705	best: 0.5813705 (500)	total: 4m 8s	remaining: 1h 18m 26s
# 600:	learn: 0.5756267	test: 0.5808870	best: 0.5808870 (600)	total: 4m 57s	remaining: 1h 17m 27s
# 700:	learn: 0.5742148	test: 0.5804890	best: 0.5804827 (698)	total: 5m 46s	remaining: 1h 16m 31s
# 800:	learn: 0.5730282	test: 0.5802028	best: 0.5801934 (798)	total: 6m 34s	remaining: 1h 15m 29s
# 900:	learn: 0.5718580	test: 0.5799361	best: 0.5799332 (899)	total: 7m 22s	remaining: 1h 14m 30s
# 1000:	learn: 0.5707300	test: 0.5797088	best: 0.5797073 (996)	total: 8m 11s	remaining: 1h 13m 35s
# 1100:	learn: 0.5696901	test: 0.5795344	best: 0.5795344 (1100)	total: 9m	remaining: 1h 12m 50s
# 1200:	learn: 0.5687450	test: 0.5794494	best: 0.5794494 (1200)	total: 9m 49s	remaining: 1h 12m
# 1300:	learn: 0.5677396	test: 0.5793239	best: 0.5793221 (1297)	total: 10m 38s	remaining: 1h 11m 7s
# 1400:	learn: 0.5667915	test: 0.5792016	best: 0.5792016 (1400)	total: 11m 26s	remaining: 1h 10m 13s
# 1500:	learn: 0.5658983	test: 0.5790641	best: 0.5790420 (1485)	total: 12m 15s	remaining: 1h 9m 23s
# bestTest = 0.5790419849
# bestIteration = 1485
# Shrink model to first 1486 iterations.
# 0:	learn: 0.6884191	test: 0.6884251	best: 0.6884251 (0)	total: 583ms	remaining: 1h 37m 6s
# 100:	learn: 0.5967318	test: 0.5965943	best: 0.5965943 (100)	total: 52.9s	remaining: 1h 26m 24s
# 200:	learn: 0.5907716	test: 0.5910864	best: 0.5910864 (200)	total: 1m 42s	remaining: 1h 23m 15s
# 300:	learn: 0.5880829	test: 0.5887020	best: 0.5887020 (300)	total: 2m 32s	remaining: 1h 22m 6s
# 400:	learn: 0.5863426	test: 0.5872526	best: 0.5872526 (400)	total: 3m 22s	remaining: 1h 20m 47s
# 500:	learn: 0.5848672	test: 0.5861062	best: 0.5861062 (500)	total: 4m 11s	remaining: 1h 19m 36s
# 600:	learn: 0.5837041	test: 0.5852643	best: 0.5852643 (600)	total: 5m 1s	remaining: 1h 18m 41s
# 700:	learn: 0.5826076	test: 0.5844554	best: 0.5844554 (700)	total: 5m 51s	remaining: 1h 17m 40s
# 800:	learn: 0.5817175	test: 0.5838860	best: 0.5838860 (800)	total: 6m 39s	remaining: 1h 16m 26s
# 900:	learn: 0.5809658	test: 0.5834218	best: 0.5834218 (900)	total: 7m 27s	remaining: 1h 15m 22s
# 1000:	learn: 0.5802276	test: 0.5829734	best: 0.5829720 (999)	total: 8m 17s	remaining: 1h 14m 28s
# 1100:	learn: 0.5796169	test: 0.5826035	best: 0.5826035 (1100)	total: 9m 4s	remaining: 1h 13m 24s
# 1200:	learn: 0.5790550	test: 0.5823094	best: 0.5823094 (1200)	total: 9m 53s	remaining: 1h 12m 28s
# 1300:	learn: 0.5784822	test: 0.5819874	best: 0.5819874 (1300)	total: 10m 40s	remaining: 1h 11m 24s
# 1400:	learn: 0.5779404	test: 0.5817180	best: 0.5817180 (1400)	total: 11m 29s	remaining: 1h 10m 32s
# 1500:	learn: 0.5774191	test: 0.5814750	best: 0.5814750 (1500)	total: 12m 17s	remaining: 1h 9m 38s
# 1600:	learn: 0.5769139	test: 0.5812737	best: 0.5812737 (1600)	total: 13m 5s	remaining: 1h 8m 42s
# 1700:	learn: 0.5764493	test: 0.5810818	best: 0.5810818 (1700)	total: 13m 54s	remaining: 1h 7m 50s
# 1800:	learn: 0.5759788	test: 0.5809016	best: 0.5809016 (1800)	total: 14m 42s	remaining: 1h 6m 56s
# 1900:	learn: 0.5755580	test: 0.5807571	best: 0.5807571 (1900)	total: 15m 31s	remaining: 1h 6m 7s
# 2000:	learn: 0.5751261	test: 0.5806017	best: 0.5806017 (2000)	total: 16m 19s	remaining: 1h 5m 17s
# 2100:	learn: 0.5746791	test: 0.5804109	best: 0.5804109 (2100)	total: 17m 8s	remaining: 1h 4m 28s
# 2200:	learn: 0.5742834	test: 0.5802638	best: 0.5802629 (2197)	total: 17m 57s	remaining: 1h 3m 37s
# 2300:	learn: 0.5738542	test: 0.5800960	best: 0.5800960 (2300)	total: 18m 46s	remaining: 1h 2m 49s
# 2400:	learn: 0.5735068	test: 0.5799851	best: 0.5799851 (2400)	total: 19m 34s	remaining: 1h 1m 56s
# 2500:	learn: 0.5731292	test: 0.5798886	best: 0.5798880 (2496)	total: 20m 23s	remaining: 1h 1m 8s
# 2600:	learn: 0.5727452	test: 0.5797685	best: 0.5797676 (2598)	total: 21m 12s	remaining: 1h 20s
# 2700:	learn: 0.5723667	test: 0.5796658	best: 0.5796658 (2700)	total: 22m 1s	remaining: 59m 32s
# 2800:	learn: 0.5720193	test: 0.5795850	best: 0.5795850 (2800)	total: 22m 51s	remaining: 58m 44s
# 2900:	learn: 0.5716732	test: 0.5794929	best: 0.5794920 (2899)	total: 23m 40s	remaining: 57m 56s
# 3000:	learn: 0.5713430	test: 0.5793949	best: 0.5793948 (2998)	total: 24m 30s	remaining: 57m 8s
# 3100:	learn: 0.5709947	test: 0.5792913	best: 0.5792908 (3099)	total: 25m 18s	remaining: 56m 18s
# 3200:	learn: 0.5706599	test: 0.5791930	best: 0.5791930 (3200)	total: 26m 8s	remaining: 55m 31s
# 3300:	learn: 0.5703165	test: 0.5791168	best: 0.5791168 (3300)	total: 26m 57s	remaining: 54m 41s
# 3400:	learn: 0.5700000	test: 0.5790440	best: 0.5790428 (3391)	total: 27m 46s	remaining: 53m 53s
# 3500:	learn: 0.5696835	test: 0.5789881	best: 0.5789873 (3497)	total: 28m 35s	remaining: 53m 4s
# 3600:	learn: 0.5693531	test: 0.5789299	best: 0.5789299 (3600)	total: 29m 24s	remaining: 52m 16s
# 3700:	learn: 0.5690127	test: 0.5788622	best: 0.5788617 (3698)	total: 30m 14s	remaining: 51m 28s
# 3800:	learn: 0.5687189	test: 0.5788014	best: 0.5787943 (3788)	total: 31m 3s	remaining: 50m 39s
# 3900:	learn: 0.5684226	test: 0.5787667	best: 0.5787667 (3900)	total: 31m 52s	remaining: 49m 50s
# 4000:	learn: 0.5681178	test: 0.5787266	best: 0.5787266 (4000)	total: 32m 40s	remaining: 48m 59s
# 4100:	learn: 0.5678121	test: 0.5786895	best: 0.5786895 (4100)	total: 33m 30s	remaining: 48m 12s
# 4200:	learn: 0.5675218	test: 0.5786339	best: 0.5786339 (4200)	total: 34m 19s	remaining: 47m 22s
# 4300:	learn: 0.5672302	test: 0.5786082	best: 0.5786058 (4295)	total: 35m 9s	remaining: 46m 34s
# 4400:	learn: 0.5669290	test: 0.5785707	best: 0.5785692 (4399)	total: 35m 58s	remaining: 45m 45s
# 4500:	learn: 0.5666203	test: 0.5785326	best: 0.5785264 (4490)	total: 36m 48s	remaining: 44m 58s
# bestTest = 0.5785263517
# bestIteration = 4490
# Shrink model to first 4491 iterations.
# 0:	learn: 0.6848835	test: 0.6849233	best: 0.6849233 (0)	total: 814ms	remaining: 2h 15m 36s
# 100:	learn: 0.5885846	test: 0.5895584	best: 0.5895584 (100)	total: 1m 10s	remaining: 1h 54m 54s
# 200:	learn: 0.5830999	test: 0.5855695	best: 0.5855695 (200)	total: 2m 15s	remaining: 1h 50m 29s
# 300:	learn: 0.5797217	test: 0.5836596	best: 0.5836596 (300)	total: 3m 22s	remaining: 1h 48m 31s
# 400:	learn: 0.5770244	test: 0.5825147	best: 0.5825147 (400)	total: 4m 27s	remaining: 1h 46m 45s
# 500:	learn: 0.5746994	test: 0.5816625	best: 0.5816625 (500)	total: 5m 34s	remaining: 1h 45m 35s
# 600:	learn: 0.5726356	test: 0.5810628	best: 0.5810628 (600)	total: 6m 39s	remaining: 1h 44m 3s
# 700:	learn: 0.5706092	test: 0.5805225	best: 0.5805225 (700)	total: 7m 44s	remaining: 1h 42m 36s
# 800:	learn: 0.5687826	test: 0.5801593	best: 0.5801560 (798)	total: 8m 51s	remaining: 1h 41m 40s
# 900:	learn: 0.5669965	test: 0.5798803	best: 0.5798803 (900)	total: 9m 56s	remaining: 1h 40m 21s
# 1000:	learn: 0.5652504	test: 0.5796253	best: 0.5796253 (1000)	total: 11m 1s	remaining: 1h 39m 4s
# 1100:	learn: 0.5635571	test: 0.5793702	best: 0.5793694 (1099)	total: 12m 7s	remaining: 1h 38m 1s
# 1200:	learn: 0.5619983	test: 0.5792426	best: 0.5792334 (1195)	total: 13m 13s	remaining: 1h 36m 55s
# 1300:	learn: 0.5604705	test: 0.5790929	best: 0.5790888 (1299)	total: 14m 18s	remaining: 1h 35m 43s
# 1400:	learn: 0.5589089	test: 0.5789834	best: 0.5789759 (1396)	total: 15m 25s	remaining: 1h 34m 42s
# 1500:	learn: 0.5573910	test: 0.5789647	best: 0.5789550 (1476)	total: 16m 31s	remaining: 1h 33m 35s
# 1600:	learn: 0.5559502	test: 0.5788875	best: 0.5788702 (1587)	total: 17m 37s	remaining: 1h 32m 27s
# 1700:	learn: 0.5545069	test: 0.5788261	best: 0.5788261 (1700)	total: 18m 40s	remaining: 1h 31m 6s
# 1800:	learn: 0.5530472	test: 0.5787730	best: 0.5787670 (1776)	total: 19m 46s	remaining: 1h 30m 2s
# 1900:	learn: 0.5514990	test: 0.5787560	best: 0.5787419 (1899)	total: 20m 55s	remaining: 1h 29m 7s
# bestTest = 0.5787418816
# bestIteration = 1899
# Shrink model to first 1900 iterations.
# 0:	learn: 0.6848834	test: 0.6849233	best: 0.6849233 (0)	total: 813ms	remaining: 2h 15m 25s
# 100:	learn: 0.5886279	test: 0.5895974	best: 0.5895974 (100)	total: 1m 9s	remaining: 1h 53m 46s
# 200:	learn: 0.5832594	test: 0.5857386	best: 0.5857386 (200)	total: 2m 14s	remaining: 1h 49m 37s
# 300:	learn: 0.5799013	test: 0.5838347	best: 0.5838347 (300)	total: 3m 21s	remaining: 1h 48m 11s
# 400:	learn: 0.5772479	test: 0.5825828	best: 0.5825828 (400)	total: 4m 28s	remaining: 1h 46m 56s
# 500:	learn: 0.5749737	test: 0.5817077	best: 0.5817077 (500)	total: 5m 33s	remaining: 1h 45m 29s
# 600:	learn: 0.5729040	test: 0.5811109	best: 0.5811109 (600)	total: 6m 39s	remaining: 1h 44m 2s
# 700:	learn: 0.5708697	test: 0.5805805	best: 0.5805805 (700)	total: 7m 44s	remaining: 1h 42m 35s
# 800:	learn: 0.5690426	test: 0.5801208	best: 0.5801138 (798)	total: 8m 48s	remaining: 1h 41m 12s
# 900:	learn: 0.5672333	test: 0.5798256	best: 0.5798256 (900)	total: 9m 53s	remaining: 1h 39m 57s
# 1000:	learn: 0.5655922	test: 0.5795948	best: 0.5795948 (1000)	total: 10m 58s	remaining: 1h 38m 41s
# 1100:	learn: 0.5639646	test: 0.5793614	best: 0.5793614 (1100)	total: 12m 4s	remaining: 1h 37m 36s
# 1200:	learn: 0.5623803	test: 0.5792315	best: 0.5792285 (1199)	total: 13m 9s	remaining: 1h 36m 24s
# 1300:	learn: 0.5609114	test: 0.5790539	best: 0.5790539 (1300)	total: 14m 14s	remaining: 1h 35m 14s
# 1400:	learn: 0.5593618	test: 0.5788843	best: 0.5788728 (1390)	total: 15m 18s	remaining: 1h 33m 58s
# bestTest = 0.5788677505
# bestIteration = 1405
# Shrink model to first 1406 iterations.
# 0:	learn: 0.6881294	test: 0.6881542	best: 0.6881542 (0)	total: 815ms	remaining: 2h 15m 46s
# 100:	learn: 0.5930929	test: 0.5935173	best: 0.5935173 (100)	total: 1m 8s	remaining: 1h 51m 57s
# 200:	learn: 0.5873074	test: 0.5886339	best: 0.5886339 (200)	total: 2m 16s	remaining: 1h 50m 49s
# 300:	learn: 0.5840910	test: 0.5863167	best: 0.5863167 (300)	total: 3m 23s	remaining: 1h 49m 19s
# 400:	learn: 0.5818392	test: 0.5849043	best: 0.5849043 (400)	total: 4m 28s	remaining: 1h 47m 1s
# 500:	learn: 0.5798902	test: 0.5838342	best: 0.5838342 (500)	total: 5m 33s	remaining: 1h 45m 21s
# 600:	learn: 0.5781123	test: 0.5829016	best: 0.5829016 (600)	total: 6m 39s	remaining: 1h 44m 1s
# 700:	learn: 0.5765463	test: 0.5822767	best: 0.5822767 (700)	total: 7m 45s	remaining: 1h 42m 53s
# 800:	learn: 0.5751676	test: 0.5817720	best: 0.5817720 (800)	total: 8m 51s	remaining: 1h 41m 44s
# 900:	learn: 0.5738498	test: 0.5813444	best: 0.5813444 (900)	total: 9m 55s	remaining: 1h 40m 17s
# 1000:	learn: 0.5725641	test: 0.5809072	best: 0.5809045 (999)	total: 11m 1s	remaining: 1h 39m 9s
# 1100:	learn: 0.5714081	test: 0.5806114	best: 0.5806114 (1100)	total: 12m 8s	remaining: 1h 38m 4s
# 1200:	learn: 0.5703600	test: 0.5803586	best: 0.5803578 (1198)	total: 13m 12s	remaining: 1h 36m 48s
# 1300:	learn: 0.5692707	test: 0.5800432	best: 0.5800432 (1300)	total: 14m 17s	remaining: 1h 35m 32s
# 1400:	learn: 0.5682032	test: 0.5798103	best: 0.5798103 (1400)	total: 15m 23s	remaining: 1h 34m 29s
# 1500:	learn: 0.5671246	test: 0.5796355	best: 0.5796307 (1499)	total: 16m 29s	remaining: 1h 33m 21s
# 1600:	learn: 0.5661345	test: 0.5794594	best: 0.5794594 (1600)	total: 17m 34s	remaining: 1h 32m 14s
# 1700:	learn: 0.5651332	test: 0.5792899	best: 0.5792847 (1697)	total: 18m 39s	remaining: 1h 31m 1s
# 1800:	learn: 0.5641898	test: 0.5792047	best: 0.5792021 (1798)	total: 19m 44s	remaining: 1h 29m 51s
# 1900:	learn: 0.5632133	test: 0.5790894	best: 0.5790886 (1895)	total: 20m 50s	remaining: 1h 28m 49s
# 2000:	learn: 0.5622352	test: 0.5789279	best: 0.5789252 (1998)	total: 21m 55s	remaining: 1h 27m 39s
# 2100:	learn: 0.5612809	test: 0.5788397	best: 0.5788340 (2098)	total: 23m	remaining: 1h 26m 30s
# 2200:	learn: 0.5603480	test: 0.5787561	best: 0.5787555 (2199)	total: 24m 7s	remaining: 1h 25m 27s
# 2300:	learn: 0.5594065	test: 0.5786410	best: 0.5786410 (2300)	total: 25m 12s	remaining: 1h 24m 22s
# 2400:	learn: 0.5585207	test: 0.5785769	best: 0.5785769 (2400)	total: 26m 19s	remaining: 1h 23m 18s
# 2500:	learn: 0.5576462	test: 0.5785498	best: 0.5785355 (2455)	total: 27m 25s	remaining: 1h 22m 13s
# bestTest = 0.5785354698
# bestIteration = 2455
# Shrink model to first 2456 iterations.
# Nejlepší F1 v iteraci 2: 0.1514 (práh: 0.7316)
# Skóre se nezlepšilo. Patience: 1/2
# Odstraněno 20 nejméně důležitých příznaků.
#
# === Iterace 3 ===
# Počet příznaků: 180
# 0:	learn: 0.6884193	test: 0.6884253	best: 0.6884253 (0)	total: 565ms	remaining: 1h 34m 14s
# 100:	learn: 0.5966313	test: 0.5964657	best: 0.5964657 (100)	total: 53.6s	remaining: 1h 27m 36s
# 200:	learn: 0.5907492	test: 0.5910193	best: 0.5910193 (200)	total: 1m 42s	remaining: 1h 23m 37s
# 300:	learn: 0.5880543	test: 0.5886405	best: 0.5886405 (300)	total: 2m 31s	remaining: 1h 21m 36s
# 400:	learn: 0.5862347	test: 0.5871438	best: 0.5871438 (400)	total: 3m 21s	remaining: 1h 20m 32s
# 500:	learn: 0.5848255	test: 0.5860684	best: 0.5860684 (500)	total: 4m 11s	remaining: 1h 19m 19s
# 600:	learn: 0.5836399	test: 0.5852173	best: 0.5852173 (600)	total: 5m 1s	remaining: 1h 18m 33s
# 700:	learn: 0.5825483	test: 0.5844468	best: 0.5844468 (700)	total: 5m 51s	remaining: 1h 17m 43s
# 800:	learn: 0.5817006	test: 0.5839076	best: 0.5839076 (800)	total: 6m 41s	remaining: 1h 16m 49s
# 900:	learn: 0.5809400	test: 0.5834363	best: 0.5834363 (900)	total: 7m 31s	remaining: 1h 15m 55s
# 1000:	learn: 0.5801832	test: 0.5829505	best: 0.5829490 (999)	total: 8m 21s	remaining: 1h 15m 5s
# 1100:	learn: 0.5795666	test: 0.5826050	best: 0.5826050 (1100)	total: 9m 10s	remaining: 1h 14m 12s
# 1200:	learn: 0.5789769	test: 0.5822953	best: 0.5822953 (1200)	total: 10m	remaining: 1h 13m 22s
# 1300:	learn: 0.5783671	test: 0.5819485	best: 0.5819485 (1300)	total: 10m 50s	remaining: 1h 12m 28s
# 1400:	learn: 0.5777900	test: 0.5816563	best: 0.5816563 (1400)	total: 11m 40s	remaining: 1h 11m 37s
# 1500:	learn: 0.5772688	test: 0.5814103	best: 0.5814103 (1500)	total: 12m 30s	remaining: 1h 10m 46s
# 1600:	learn: 0.5767832	test: 0.5811995	best: 0.5811995 (1600)	total: 13m 19s	remaining: 1h 9m 52s
# 1700:	learn: 0.5763156	test: 0.5810243	best: 0.5810243 (1700)	total: 14m 7s	remaining: 1h 8m 56s
# 1800:	learn: 0.5758617	test: 0.5808530	best: 0.5808530 (1800)	total: 14m 56s	remaining: 1h 8m 1s
# 1900:	learn: 0.5754171	test: 0.5807103	best: 0.5807103 (1900)	total: 15m 48s	remaining: 1h 7m 18s
# 2000:	learn: 0.5749784	test: 0.5805533	best: 0.5805533 (2000)	total: 16m 37s	remaining: 1h 6m 28s
# 2100:	learn: 0.5745499	test: 0.5803809	best: 0.5803799 (2098)	total: 17m 27s	remaining: 1h 5m 36s
# 2200:	learn: 0.5741224	test: 0.5801994	best: 0.5801994 (2200)	total: 18m 17s	remaining: 1h 4m 49s
# 2300:	learn: 0.5737121	test: 0.5800656	best: 0.5800656 (2300)	total: 19m 8s	remaining: 1h 4m 1s
# 2400:	learn: 0.5733385	test: 0.5799504	best: 0.5799504 (2400)	total: 19m 57s	remaining: 1h 3m 10s
# 2500:	learn: 0.5729566	test: 0.5798575	best: 0.5798575 (2500)	total: 20m 48s	remaining: 1h 2m 22s
# 2600:	learn: 0.5725912	test: 0.5797463	best: 0.5797457 (2597)	total: 21m 37s	remaining: 1h 1m 30s
# 2700:	learn: 0.5722045	test: 0.5796392	best: 0.5796392 (2700)	total: 22m 27s	remaining: 1h 41s
# 2800:	learn: 0.5718585	test: 0.5795391	best: 0.5795391 (2800)	total: 23m 17s	remaining: 59m 52s
# 2900:	learn: 0.5715005	test: 0.5794451	best: 0.5794434 (2898)	total: 24m 8s	remaining: 59m 4s
# 3000:	learn: 0.5711526	test: 0.5793630	best: 0.5793623 (2998)	total: 24m 58s	remaining: 58m 15s
# 3100:	learn: 0.5707947	test: 0.5792639	best: 0.5792632 (3098)	total: 25m 48s	remaining: 57m 25s
# 3200:	learn: 0.5704456	test: 0.5791542	best: 0.5791542 (3200)	total: 26m 38s	remaining: 56m 36s
# 3300:	learn: 0.5701078	test: 0.5790789	best: 0.5790789 (3300)	total: 27m 28s	remaining: 55m 45s
# 3400:	learn: 0.5697831	test: 0.5790031	best: 0.5790031 (3400)	total: 28m 19s	remaining: 54m 57s
# 3500:	learn: 0.5694645	test: 0.5789427	best: 0.5789423 (3499)	total: 29m 8s	remaining: 54m 6s
# 3600:	learn: 0.5691365	test: 0.5788940	best: 0.5788940 (3600)	total: 29m 58s	remaining: 53m 15s
# 3700:	learn: 0.5687836	test: 0.5788134	best: 0.5788134 (3700)	total: 30m 49s	remaining: 52m 27s
# 3800:	learn: 0.5684720	test: 0.5787348	best: 0.5787342 (3798)	total: 31m 40s	remaining: 51m 39s
# 3900:	learn: 0.5681638	test: 0.5786930	best: 0.5786887 (3897)	total: 32m 31s	remaining: 50m 51s
# 4000:	learn: 0.5678611	test: 0.5786409	best: 0.5786409 (3999)	total: 33m 22s	remaining: 50m 2s
# 4100:	learn: 0.5675420	test: 0.5785963	best: 0.5785963 (4100)	total: 34m 14s	remaining: 49m 15s
# 4200:	learn: 0.5672522	test: 0.5785484	best: 0.5785472 (4198)	total: 35m 3s	remaining: 48m 23s
# ...
# 2500:	learn: 0.5673227	test: 0.5788286	best: 0.5788286 (2500)	total: 13m 48s	remaining: 41m 25s
# 2600:	learn: 0.5668028	test: 0.5787464	best: 0.5787464 (2600)	total: 14m 21s	remaining: 40m 50s
# 2700:	learn: 0.5662649	test: 0.5786553	best: 0.5786553 (2700)	total: 14m 54s	remaining: 40m 18s
# 2800:	learn: 0.5657704	test: 0.5786046	best: 0.5786025 (2799)	total: 15m 27s	remaining: 39m 45s
# 2900:	learn: 0.5652657	test: 0.5785437	best: 0.5785437 (2900)	total: 16m 1s	remaining: 39m 12s
# 3000:	learn: 0.5647935	test: 0.5784676	best: 0.5784676 (3000)	total: 16m 35s	remaining: 38m 41s
# 3100:	learn: 0.5643155	test: 0.5783954	best: 0.5783935 (3099)	total: 17m 8s	remaining: 38m 7s
# 3200:	learn: 0.5638314	test: 0.5783485	best: 0.5783480 (3198)	total: 17m 42s	remaining: 37m 36s
# bestTest = 0.57833996
# bestIteration = 3207
# Shrink model to first 3208 iterations.
# 0:	learn: 0.6780207	test: 0.6780395	best: 0.6780395 (0)	total: 388ms	remaining: 1h 4m 43s
# 100:	learn: 0.5877784	test: 0.5884455	best: 0.5884455 (100)	total: 34.8s	remaining: 56m 48s
# 200:	learn: 0.5830719	test: 0.5847442	best: 0.5847442 (200)	total: 1m 8s	remaining: 55m 34s
# 300:	learn: 0.5803711	test: 0.5830451	best: 0.5830451 (300)	total: 1m 41s	remaining: 54m 40s
# 400:	learn: 0.5784131	test: 0.5819837	best: 0.5819837 (400)	total: 2m 14s	remaining: 53m 34s
# 500:	learn: 0.5768221	test: 0.5813006	best: 0.5813006 (500)	total: 2m 46s	remaining: 52m 46s
# 600:	learn: 0.5753228	test: 0.5807202	best: 0.5807202 (600)	total: 3m 19s	remaining: 52m 6s
# 700:	learn: 0.5739847	test: 0.5802901	best: 0.5802901 (700)	total: 3m 52s	remaining: 51m 27s
# 800:	learn: 0.5728816	test: 0.5801020	best: 0.5801011 (799)	total: 4m 25s	remaining: 50m 45s
# 900:	learn: 0.5716662	test: 0.5797482	best: 0.5797482 (900)	total: 4m 57s	remaining: 50m 3s
# 1000:	learn: 0.5704926	test: 0.5794739	best: 0.5794739 (1000)	total: 5m 30s	remaining: 49m 31s
# 1100:	learn: 0.5694936	test: 0.5792080	best: 0.5792080 (1100)	total: 6m 3s	remaining: 48m 58s
# 1200:	learn: 0.5684602	test: 0.5790944	best: 0.5790883 (1198)	total: 6m 36s	remaining: 48m 26s
# 1300:	learn: 0.5674890	test: 0.5789276	best: 0.5789275 (1294)	total: 7m 9s	remaining: 47m 49s
# 1400:	learn: 0.5664998	test: 0.5788179	best: 0.5787996 (1394)	total: 7m 42s	remaining: 47m 16s
# bestTest = 0.5787763717
# bestIteration = 1442
# Shrink model to first 1443 iterations.
# 0:	learn: 0.6780204	test: 0.6780390	best: 0.6780390 (0)	total: 380ms	remaining: 1h 3m 21s
# 100:	learn: 0.5877751	test: 0.5884457	best: 0.5884457 (100)	total: 34.7s	remaining: 56m 41s
# 200:	learn: 0.5830859	test: 0.5848038	best: 0.5848038 (200)	total: 1m 8s	remaining: 55m 20s
# 300:	learn: 0.5804215	test: 0.5831929	best: 0.5831929 (300)	total: 1m 41s	remaining: 54m 17s
# 400:	learn: 0.5784373	test: 0.5820798	best: 0.5820798 (400)	total: 2m 14s	remaining: 53m 33s
# 500:	learn: 0.5767509	test: 0.5812783	best: 0.5812764 (499)	total: 2m 46s	remaining: 52m 45s
# 600:	learn: 0.5753454	test: 0.5807563	best: 0.5807563 (600)	total: 3m 19s	remaining: 51m 52s
# 700:	learn: 0.5740357	test: 0.5804922	best: 0.5804823 (695)	total: 3m 51s	remaining: 51m 15s
# 800:	learn: 0.5728436	test: 0.5802294	best: 0.5802293 (799)	total: 4m 24s	remaining: 50m 40s
# 900:	learn: 0.5716757	test: 0.5798931	best: 0.5798899 (898)	total: 4m 57s	remaining: 50m 5s
# 1000:	learn: 0.5704590	test: 0.5795838	best: 0.5795838 (1000)	total: 5m 31s	remaining: 49m 37s
# 1100:	learn: 0.5694808	test: 0.5794001	best: 0.5793965 (1095)	total: 6m 5s	remaining: 49m 13s
# 1200:	learn: 0.5684494	test: 0.5792506	best: 0.5792304 (1189)	total: 6m 38s	remaining: 48m 40s
# bestTest = 0.5792304248
# bestIteration = 1189
# Shrink model to first 1190 iterations.
# 0:	learn: 0.6884194	test: 0.6884255	best: 0.6884255 (0)	total: 373ms	remaining: 1h 2m 9s
# 100:	learn: 0.5963666	test: 0.5960537	best: 0.5960537 (100)	total: 35.5s	remaining: 58m 1s
# 200:	learn: 0.5905062	test: 0.5906810	best: 0.5906810 (200)	total: 1m 9s	remaining: 56m 23s
# 300:	learn: 0.5879194	test: 0.5884461	best: 0.5884461 (300)	total: 1m 43s	remaining: 55m 38s
# 400:	learn: 0.5861887	test: 0.5870580	best: 0.5870580 (400)	total: 2m 17s	remaining: 54m 42s
# 500:	learn: 0.5848373	test: 0.5860264	best: 0.5860264 (500)	total: 2m 51s	remaining: 54m 6s
# 600:	learn: 0.5836807	test: 0.5851800	best: 0.5851800 (600)	total: 3m 25s	remaining: 53m 33s
# 700:	learn: 0.5826023	test: 0.5843766	best: 0.5843766 (700)	total: 3m 58s	remaining: 52m 46s
# 800:	learn: 0.5817422	test: 0.5838357	best: 0.5838357 (800)	total: 4m 32s	remaining: 52m 11s
# 900:	learn: 0.5809633	test: 0.5833474	best: 0.5833474 (900)	total: 5m 6s	remaining: 51m 33s
# 1000:	learn: 0.5802082	test: 0.5828769	best: 0.5828760 (999)	total: 5m 39s	remaining: 50m 55s
# 1100:	learn: 0.5795825	test: 0.5825122	best: 0.5825122 (1100)	total: 6m 13s	remaining: 50m 22s
# 1200:	learn: 0.5789593	test: 0.5821674	best: 0.5821674 (1200)	total: 6m 47s	remaining: 49m 45s
# 1300:	learn: 0.5783890	test: 0.5818669	best: 0.5818669 (1300)	total: 7m 21s	remaining: 49m 13s
# 1400:	learn: 0.5778059	test: 0.5815752	best: 0.5815752 (1400)	total: 7m 55s	remaining: 48m 40s
# 1500:	learn: 0.5772800	test: 0.5813308	best: 0.5813308 (1500)	total: 8m 30s	remaining: 48m 8s
# 1600:	learn: 0.5767668	test: 0.5811047	best: 0.5811047 (1600)	total: 9m 4s	remaining: 47m 34s
# 1700:	learn: 0.5763087	test: 0.5809183	best: 0.5809183 (1700)	total: 9m 36s	remaining: 46m 54s
# 1800:	learn: 0.5758589	test: 0.5807516	best: 0.5807516 (1800)	total: 10m 9s	remaining: 46m 16s
# 1900:	learn: 0.5754394	test: 0.5806159	best: 0.5806159 (1899)	total: 10m 43s	remaining: 45m 41s
# 2000:	learn: 0.5750049	test: 0.5804417	best: 0.5804404 (1999)	total: 11m 17s	remaining: 45m 9s
# 2100:	learn: 0.5745602	test: 0.5802652	best: 0.5802646 (2099)	total: 11m 51s	remaining: 44m 36s
# 2200:	learn: 0.5741549	test: 0.5801348	best: 0.5801344 (2198)	total: 12m 25s	remaining: 44m 2s
# 2300:	learn: 0.5737367	test: 0.5799919	best: 0.5799913 (2298)	total: 13m	remaining: 43m 30s
# 2400:	learn: 0.5733620	test: 0.5798781	best: 0.5798781 (2400)	total: 13m 34s	remaining: 42m 56s
# 2500:	learn: 0.5729706	test: 0.5797466	best: 0.5797463 (2499)	total: 14m 8s	remaining: 42m 23s
# 2600:	learn: 0.5725678	test: 0.5796240	best: 0.5796239 (2598)	total: 14m 42s	remaining: 41m 51s
# 2700:	learn: 0.5722003	test: 0.5795142	best: 0.5795142 (2700)	total: 15m 16s	remaining: 41m 17s
# 2800:	learn: 0.5718503	test: 0.5794140	best: 0.5794140 (2800)	total: 15m 51s	remaining: 40m 44s
# 2900:	learn: 0.5714728	test: 0.5793165	best: 0.5793165 (2900)	total: 16m 25s	remaining: 40m 11s
# 3000:	learn: 0.5711317	test: 0.5792270	best: 0.5792267 (2999)	total: 16m 59s	remaining: 39m 37s
# 3100:	learn: 0.5707887	test: 0.5791231	best: 0.5791231 (3100)	total: 17m 33s	remaining: 39m 3s
# 3200:	learn: 0.5704605	test: 0.5790389	best: 0.5790389 (3200)	total: 18m 7s	remaining: 38m 30s
# 3300:	learn: 0.5701277	test: 0.5789836	best: 0.5789836 (3300)	total: 18m 42s	remaining: 37m 57s
# 3400:	learn: 0.5697950	test: 0.5788997	best: 0.5788997 (3400)	total: 19m 16s	remaining: 37m 24s
# 3500:	learn: 0.5694749	test: 0.5788309	best: 0.5788309 (3500)	total: 19m 51s	remaining: 36m 51s
# 3600:	learn: 0.5691359	test: 0.5787488	best: 0.5787488 (3600)	total: 20m 26s	remaining: 36m 19s
# 3700:	learn: 0.5688035	test: 0.5786740	best: 0.5786740 (3700)	total: 21m 1s	remaining: 35m 46s
# 3800:	learn: 0.5684861	test: 0.5785955	best: 0.5785905 (3773)	total: 21m 35s	remaining: 35m 13s
# 3900:	learn: 0.5681773	test: 0.5785422	best: 0.5785422 (3900)	total: 22m 10s	remaining: 34m 39s
# 4000:	learn: 0.5678682	test: 0.5784855	best: 0.5784849 (3999)	total: 22m 45s	remaining: 34m 7s
# 4100:	learn: 0.5675656	test: 0.5784416	best: 0.5784416 (4099)	total: 23m 20s	remaining: 33m 33s
# 4200:	learn: 0.5672771	test: 0.5783810	best: 0.5783810 (4200)	total: 23m 53s	remaining: 32m 59s
# 4300:	learn: 0.5669913	test: 0.5783555	best: 0.5783544 (4295)	total: 24m 28s	remaining: 32m 25s
# 4400:	learn: 0.5666987	test: 0.5782984	best: 0.5782971 (4399)	total: 25m 3s	remaining: 31m 52s
# 4500:	learn: 0.5663848	test: 0.5782421	best: 0.5782393 (4499)	total: 25m 36s	remaining: 31m 17s
# 4600:	learn: 0.5660930	test: 0.5782056	best: 0.5782051 (4599)	total: 26m 9s	remaining: 30m 41s
# 4700:	learn: 0.5657900	test: 0.5781283	best: 0.5781266 (4699)	total: 26m 43s	remaining: 30m 7s
# 4800:	learn: 0.5654959	test: 0.5780713	best: 0.5780704 (4796)	total: 27m 16s	remaining: 29m 32s
# 4900:	learn: 0.5652011	test: 0.5780356	best: 0.5780332 (4897)	total: 27m 50s	remaining: 28m 57s
# 5000:	learn: 0.5649179	test: 0.5780120	best: 0.5780120 (5000)	total: 28m 22s	remaining: 28m 21s
# 5100:	learn: 0.5646313	test: 0.5779883	best: 0.5779877 (5099)	total: 28m 55s	remaining: 27m 47s
# 5200:	learn: 0.5643699	test: 0.5779353	best: 0.5779353 (5200)	total: 29m 29s	remaining: 27m 12s
# 5300:	learn: 0.5640878	test: 0.5779032	best: 0.5779032 (5300)	total: 30m 3s	remaining: 26m 38s
# 5400:	learn: 0.5638143	test: 0.5778946	best: 0.5778938 (5356)	total: 30m 36s	remaining: 26m 4s
# bestTest = 0.5778816782
# bestIteration = 5444
# Shrink model to first 5445 iterations.
# 0:	learn: 0.6848448	test: 0.6848848	best: 0.6848848 (0)	total: 542ms	remaining: 1h 30m 23s
# 100:	learn: 0.5886232	test: 0.5897089	best: 0.5897089 (100)	total: 46.7s	remaining: 1h 16m 21s
# 200:	learn: 0.5834090	test: 0.5859892	best: 0.5859892 (200)	total: 1m 32s	remaining: 1h 15m 11s
# 300:	learn: 0.5798716	test: 0.5839233	best: 0.5839233 (300)	total: 2m 15s	remaining: 1h 13m
# 400:	learn: 0.5770395	test: 0.5825705	best: 0.5825705 (400)	total: 3m	remaining: 1h 12m
# 500:	learn: 0.5746147	test: 0.5816254	best: 0.5816254 (500)	total: 3m 44s	remaining: 1h 10m 54s
# 600:	learn: 0.5724258	test: 0.5810301	best: 0.5810293 (598)	total: 4m 29s	remaining: 1h 10m 6s
# 700:	learn: 0.5703664	test: 0.5806099	best: 0.5806099 (700)	total: 5m 13s	remaining: 1h 9m 19s
# 800:	learn: 0.5684767	test: 0.5802538	best: 0.5802520 (799)	total: 5m 57s	remaining: 1h 8m 24s
# 900:	learn: 0.5666653	test: 0.5798422	best: 0.5798422 (900)	total: 6m 41s	remaining: 1h 7m 30s
# 1000:	learn: 0.5649273	test: 0.5795841	best: 0.5795841 (1000)	total: 7m 25s	remaining: 1h 6m 42s
# 1100:	learn: 0.5632803	test: 0.5793666	best: 0.5793486 (1095)	total: 8m 8s	remaining: 1h 5m 51s
# 1200:	learn: 0.5616595	test: 0.5792216	best: 0.5792216 (1200)	total: 8m 53s	remaining: 1h 5m 11s
# 1300:	learn: 0.5600536	test: 0.5790290	best: 0.5790251 (1299)	total: 9m 38s	remaining: 1h 4m 27s
# 1400:	learn: 0.5584343	test: 0.5789418	best: 0.5789352 (1380)	total: 10m 24s	remaining: 1h 3m 55s
# 1500:	learn: 0.5568569	test: 0.5788544	best: 0.5788359 (1496)	total: 11m 10s	remaining: 1h 3m 18s
# 1600:	learn: 0.5553650	test: 0.5788175	best: 0.5788122 (1589)	total: 11m 55s	remaining: 1h 2m 33s
# bestTest = 0.5787950703
# bestIteration = 1618
# Shrink model to first 1619 iterations.
# 0:	learn: 0.6848445	test: 0.6848845	best: 0.6848845 (0)	total: 572ms	remaining: 1h 35m 16s
# 100:	learn: 0.5886431	test: 0.5897089	best: 0.5897089 (100)	total: 46.9s	remaining: 1h 16m 33s
# 200:	learn: 0.5834172	test: 0.5859299	best: 0.5859299 (200)	total: 1m 33s	remaining: 1h 15m 47s
# 300:	learn: 0.5799413	test: 0.5839240	best: 0.5839240 (300)	total: 2m 16s	remaining: 1h 13m 30s
# 400:	learn: 0.5772002	test: 0.5825466	best: 0.5825466 (400)	total: 3m 1s	remaining: 1h 12m 20s
# 500:	learn: 0.5747358	test: 0.5816862	best: 0.5816862 (500)	total: 3m 47s	remaining: 1h 11m 52s
# 600:	learn: 0.5725964	test: 0.5809882	best: 0.5809879 (599)	total: 4m 33s	remaining: 1h 11m 10s
# 700:	learn: 0.5705182	test: 0.5804622	best: 0.5804622 (700)	total: 5m 18s	remaining: 1h 10m 19s
# 800:	learn: 0.5686209	test: 0.5800466	best: 0.5800364 (798)	total: 6m 2s	remaining: 1h 9m 26s
# 900:	learn: 0.5668480	test: 0.5797038	best: 0.5797038 (900)	total: 6m 46s	remaining: 1h 8m 26s
# 1000:	learn: 0.5652177	test: 0.5794621	best: 0.5794621 (1000)	total: 7m 31s	remaining: 1h 7m 35s
# 1100:	learn: 0.5635687	test: 0.5792359	best: 0.5792337 (1095)	total: 8m 16s	remaining: 1h 6m 49s
# 1200:	learn: 0.5620127	test: 0.5790495	best: 0.5790495 (1200)	total: 8m 59s	remaining: 1h 5m 55s
# 1300:	learn: 0.5604129	test: 0.5788594	best: 0.5788594 (1300)	total: 9m 45s	remaining: 1h 5m 13s
# 1400:	learn: 0.5587996	test: 0.5787264	best: 0.5787264 (1400)	total: 10m 30s	remaining: 1h 4m 29s
# 1500:	learn: 0.5572703	test: 0.5786479	best: 0.5786348 (1494)	total: 11m 14s	remaining: 1h 3m 41s
# bestTest = 0.5786107929
# bestIteration = 1526
# Shrink model to first 1527 iterations.
# 0:	learn: 0.6881059	test: 0.6881306	best: 0.6881306 (0)	total: 552ms	remaining: 1h 32m 1s
# 100:	learn: 0.5930814	test: 0.5933739	best: 0.5933739 (100)	total: 46.3s	remaining: 1h 15m 35s
# 200:	learn: 0.5872467	test: 0.5885211	best: 0.5885211 (200)	total: 1m 32s	remaining: 1h 15m 12s
# 300:	learn: 0.5840140	test: 0.5861879	best: 0.5861879 (300)	total: 2m 18s	remaining: 1h 14m 9s
# 400:	learn: 0.5817005	test: 0.5847529	best: 0.5847529 (400)	total: 3m 3s	remaining: 1h 13m 3s
# 500:	learn: 0.5797288	test: 0.5836520	best: 0.5836520 (500)	total: 3m 49s	remaining: 1h 12m 24s
# 600:	learn: 0.5780350	test: 0.5828514	best: 0.5828514 (600)	total: 4m 33s	remaining: 1h 11m 22s
# 700:	learn: 0.5764214	test: 0.5821662	best: 0.5821662 (700)	total: 5m 18s	remaining: 1h 10m 25s
# 800:	learn: 0.5750547	test: 0.5816868	best: 0.5816868 (800)	total: 6m 3s	remaining: 1h 9m 36s
# 900:	learn: 0.5737160	test: 0.5812175	best: 0.5812175 (900)	total: 6m 47s	remaining: 1h 8m 39s
# 1000:	learn: 0.5723863	test: 0.5807838	best: 0.5807801 (996)	total: 7m 34s	remaining: 1h 8m 3s
# 1100:	learn: 0.5711703	test: 0.5804743	best: 0.5804743 (1100)	total: 8m 19s	remaining: 1h 7m 19s
# 1200:	learn: 0.5700404	test: 0.5801885	best: 0.5801872 (1199)	total: 9m 5s	remaining: 1h 6m 33s
# 1300:	learn: 0.5689736	test: 0.5799398	best: 0.5799398 (1300)	total: 9m 49s	remaining: 1h 5m 43s
# 1400:	learn: 0.5678596	test: 0.5797004	best: 0.5797004 (1400)	total: 10m 35s	remaining: 1h 5m
# 1500:	learn: 0.5668260	test: 0.5795143	best: 0.5795143 (1500)	total: 11m 20s	remaining: 1h 4m 14s
# 1600:	learn: 0.5658031	test: 0.5793552	best: 0.5793552 (1600)	total: 12m 5s	remaining: 1h 3m 27s
# 1700:	learn: 0.5647934	test: 0.5791741	best: 0.5791714 (1697)	total: 12m 50s	remaining: 1h 2m 38s
# 1800:	learn: 0.5638169	test: 0.5790867	best: 0.5790867 (1800)	total: 13m 34s	remaining: 1h 1m 48s
# 1900:	learn: 0.5628208	test: 0.5789789	best: 0.5789767 (1899)	total: 14m 20s	remaining: 1h 1m 4s
# 2000:	learn: 0.5618116	test: 0.5788344	best: 0.5788344 (2000)	total: 15m 5s	remaining: 1h 19s
# 2100:	learn: 0.5608186	test: 0.5787207	best: 0.5787195 (2099)	total: 15m 50s	remaining: 59m 35s
# 2200:	learn: 0.5598792	test: 0.5785988	best: 0.5785974 (2198)	total: 16m 37s	remaining: 58m 54s
# 2300:	learn: 0.5589554	test: 0.5784753	best: 0.5784753 (2300)	total: 17m 23s	remaining: 58m 10s
# 2400:	learn: 0.5580663	test: 0.5784532	best: 0.5784368 (2387)	total: 18m 10s	remaining: 57m 31s
# 2500:	learn: 0.5572036	test: 0.5783912	best: 0.5783896 (2498)	total: 18m 56s	remaining: 56m 48s
# 2600:	learn: 0.5562717	test: 0.5783463	best: 0.5783416 (2587)	total: 19m 42s	remaining: 56m 2s
# 2700:	learn: 0.5553401	test: 0.5782705	best: 0.5782705 (2700)	total: 20m 29s	remaining: 55m 22s
# 2800:	learn: 0.5544632	test: 0.5782314	best: 0.5782283 (2770)	total: 21m 15s	remaining: 54m 36s
# 2900:	learn: 0.5535636	test: 0.5781853	best: 0.5781822 (2897)	total: 22m 1s	remaining: 53m 53s
# 3000:	learn: 0.5526777	test: 0.5781293	best: 0.5781283 (2996)	total: 22m 46s	remaining: 53m 7s
# 3100:	learn: 0.5517635	test: 0.5780788	best: 0.5780741 (3093)	total: 23m 32s	remaining: 52m 22s
# 3200:	learn: 0.5509041	test: 0.5780512	best: 0.5780486 (3193)	total: 24m 18s	remaining: 51m 37s
# 3300:	learn: 0.5500666	test: 0.5780309	best: 0.5780309 (3300)	total: 25m 3s	remaining: 50m 51s
# 3400:	learn: 0.5491848	test: 0.5779697	best: 0.5779660 (3399)	total: 25m 48s	remaining: 50m 5s
# bestTest = 0.5779367169
# bestIteration = 3443
# Shrink model to first 3444 iterations.
# Nejlepší F1 v iteraci 7: 0.1516 (práh: 0.7506)
# Skóre se nezlepšilo. Patience: 2/2
# Early stopping aktivován. Ukončuji iterativní ladění.
#
# === Iterativní proces dokončen ===
# Nejlepší celkové F1: 0.1519 (práh: 0.7411)
# Ponecháno příznaků: 146 (65.77 % z původních 222).

# %% [markdown]
# # 8. Ulozeni vysledku

# %%
best_overall_model.save_model('model.bin')
print(best_overall_f1)
print(retained_ratio)
print(best_overall_thr)
print(best_overall_features)
print(cat_features)
# Out:
# 0.15187569367369588
# 65.76576576576578
# 0.741111111111111
# ['Stari_Vozidla_Let', 'Vozidlo_TypMotoru', 'Vysledek_Odometr', 'Nafta_MereniPrumer_Kourivost_Hodnota', 'Doba_Trvani_Emisi', 'Vozidlo_Znacka', 'Prohlidka_Stanice_Cislo', 'Prohlidka_Stanice_Obec', 'Benzin_OtackyVolnobezne_O2_Hodnota', 'Prohlidka_Stanice_Kraj', 'Prohlidka_Cas_zahajeni', 'Doba_Trvani_Prohlidky', 'MericiPristroj_VerzeSoftware', 'Benzin_OtackyVolnobezne_COCOOR_Hodnota', 'Nafta_MereniVznetLimit_Kourivost_Max_Hodnota', 'Nafta_Mereni0_Kourivost_Hodnota', 'Benzin_OtackyVolnobezne_CO_Hodnota', 'Emise_OdpovednaOsoba', 'Prohlidka_Stanice_ORP', 'Benzin_OtackyVolnobezne_N_Hodnota', 'Benzin_OtackyZvysene_CO_Hodnota', 'Benzin_OtackyVolnobezne_N_Min_Hodnota', 'Benzin_OtackyVolnobezne_CO2_Hodnota', 'Prohlidka_OdpovednaOsoba', 'Benzin_OtackyZvysene_COCOOR_Hodnota', 'Benzin_OtackyZvysene_HC_Hodnota', 'Vozidlo_ObchodniOznaceni', 'Obd_Readiness_Zazeh_CAT-FUNC_Otestovano', 'Vysledek_Readiness', 'Benzin_OtackyZvysene_LAMBDA_Hodnota', 'Nafta_MereniVznetLimit_OtackyPrebehove_Max_Hodnota', 'Vozidlo_Provedeni', 'Benzin_OtackyZvysene_O2_Hodnota', 'MericiPristroj_Verze', 'Benzin_OtackyZvysene_CO2_Hodnota', 'Obd_KomunikacniProtokol', 'Poznamky', 'Benzin_OtackyVolnobezne_N_Max_Hodnota', 'Nafta_Mereni0_CasAkcelerace_Hodnota', 'Benzin_OtackyVolnobezne_HC_Hodnota', 'Obd_VzdalenostDtc', 'Obd_Readiness_Zazeh_EGR-VVT_Podporovano', 'Nafta_MereniVznetLimit_OtackyPrebehove_Min_Hodnota', 'Nafta_Mereni0_OtackyVolnobezne_Hodnota', 'Nafta_MereniPrumer_OtackyPrebehove_Hodnota', 'MericiPristroj_Typ', 'Benzin_OtackyZvysene_N_Hodnota', 'Nafta_MereniPrumer_OtackyVolnobezne_Hodnota', 'Benzin_OtackyZvysene_N_Max_Hodnota', 'Nafta_Mereni0_TPS_Hodnota', 'Nafta_MereniPrumer_CasAkcelerace_Hodnota', 'MericiPristroj_Vyrobce', 'Nafta_Mereni0_OtackyPrebehove_Hodnota', 'Nafta_MereniVznetLimit_OtackyVolnobezne_Min_Hodnota', 'Benzin_OtackyVolnobezne_LAMBDA_Hodnota', 'MericiPristroj_OBD', 'Obd_Readiness_Vznet_RESERVE_Otestovano', 'Benzin_OtackyVolnobezne_TPS_Hodnota', 'Benzin_OtackyZvysene_CO_Max_Hodnota', 'Obd_Readiness_Vznet_DPF_Podporovano', 'Nafta_MereniVznetLimit_OtackyVolnobezne_Max_Hodnota', 'Benzin_OtackyZvysene_N_Min_Hodnota', 'Obd_Readiness_Zazeh_O2S-FUNC_Otestovano', 'Nafta_MereniPrumer_Teplota_Hodnota', 'Nafta_Mereni0_Teplota_Hodnota', 'Nafta_Mereni1_Kourivost_Hodnota', 'Obd_Readiness_Vznet_BOOST_Podporovano', 'Obd_Readiness_Zazeh_EVAP_Podporovano', 'Nafta_Mereni1_OtackyVolnobezne_Hodnota', 'Obd_Readiness_Zazeh_AC_Otestovano', 'Nafta_Mereni1_CasAkcelerace_Hodnota', 'Obd_Readiness_Vznet_EGS_Podporovano', 'Obd_Readiness_Zazeh_O2S-HEAT_Otestovano', 'Benzin_OtackyVolnobezne_CO_Max_Hodnota', 'Obd_Readiness_Vznet_NOX_Podporovano', 'Obd_PocetDtc', 'Registrace_Stat', 'Benzin_OtackyZvysene_TPS_Hodnota', 'Nafta_Mereni3_TPS_Hodnota', 'Obd_Readiness_Zazeh_O2S-HEAT_Podporovano', 'Benzin_OtackyZvysene_LAMBDA_Max_Hodnota', 'Vozidlo_Druh', 'Nafta_MereniPrumer_TPS_Hodnota', 'Obd_Readiness_Vznet_NMHC_Podporovano', 'AdministrativneOpraveno', 'Nafta_Mereni1_OtackyPrebehove_Hodnota', 'Obd_Readiness_Zazeh_FUEL_Podporovano', 'Obd_Readiness_Vznet_EGR-VVT_Otestovano', 'Benzin_OtackyVolnobezne_LAMBDA_Vysledek', 'Obd_Readiness_Vznet_EGS_Otestovano', 'Obd_Readiness_Zazeh_SAS_Podporovano', 'Obd_Readiness_Vznet_FUEL_Podporovano', 'Nafta_Mereni3_Teplota_Vysledek', 'Benzin_OtackyVolnobezne_HC_Max_RucniZadani', 'Obd_VypisDtc', 'Zavady', 'Obd_Readiness_Zazeh_FUEL_Otestovano', 'Benzin_PocetVyusteni', 'Obd_Readiness_Vznet_COMP_Podporovano', 'Obd_Readiness_Zazeh_HCAT_Podporovano', 'Obd_Readiness_Vznet_FUEL_Otestovano', 'Nafta_MereniVznetLimit_OtackyPrebehove_Min_RucniZadani', 'Obd_Readiness_Vysledek', 'Obd_Readiness_Vznet_EGR-VVT_Podporovano', 'Benzin_OtackyZvysene_HC_Vysledek', 'Benzin_OtackyVolnobezne_LAMBDA_Max_RucniZadani', 'Obd_Readiness_Zazeh_COMP_Otestovano', 'Obd_Readiness_Zazeh_EGR-VVT_Otestovano', 'Obd_Readiness_Zazeh_SAS_Otestovano', 'Benzin_OtackyZvysene_LAMBDA_Max_RucniZadani', 'Nafta_Mereni3_CasAkcelerace_Hodnota', 'Nafta_Mereni1_Teplota_Hodnota', 'Obd_Readiness_Vznet_NOX_Otestovano',  ...
# ['Prohlidka_OdpovednaOsoba', 'Prohlidka_Stanice_Cislo', 'Prohlidka_Stanice_Kraj', 'Prohlidka_Stanice_ORP', 'Prohlidka_Stanice_Obec', 'Vozidlo_Druh', 'Vozidlo_Provedeni', 'Vozidlo_Znacka', 'Vozidlo_ObchodniOznaceni', 'Vozidlo_TypMotoru', 'Registrace_Stat', 'Emise_OdpovednaOsoba', 'Emise_ZakladniPalivo', 'TechnickaCast_Pritomno', 'AdrCast_Pritomno', 'TskCast_Pritomno', 'AdministrativneOpraveno', 'MericiPristroj_Vyrobce', 'MericiPristroj_Typ', 'MericiPristroj_Verze', 'MericiPristroj_OBD', 'MericiPristroj_VerzeSoftware', 'Vysledek_VisualniKontrola', 'Vysledek_Readiness', 'Vysledek_Vyhovuje', 'Obd_Readiness_Vysledek', 'OBD_Pritomno', 'Obd_KomunikacniProtokol', 'Obd_Readiness_Zazeh_AC_Otestovano', 'Obd_Readiness_Zazeh_AC_Podporovano', 'Obd_Readiness_Zazeh_CAT-FUNC_Otestovano', 'Obd_Readiness_Zazeh_CAT-FUNC_Podporovano', 'Obd_Readiness_Zazeh_COMP_Otestovano', 'Obd_Readiness_Zazeh_COMP_Podporovano', 'Obd_Readiness_Zazeh_EGR-VVT_Otestovano', 'Obd_Readiness_Zazeh_EGR-VVT_Podporovano', 'Obd_Readiness_Zazeh_EVAP_Otestovano', 'Obd_Readiness_Zazeh_EVAP_Podporovano', 'Obd_Readiness_Zazeh_FUEL_Otestovano', 'Obd_Readiness_Zazeh_FUEL_Podporovano', 'Obd_Readiness_Zazeh_HCAT_Otestovano', 'Obd_Readiness_Zazeh_HCAT_Podporovano', 'Obd_Readiness_Zazeh_MISF_Otestovano', 'Obd_Readiness_Zazeh_MISF_Podporovano', 'Obd_Readiness_Zazeh_O2S-FUNC_Otestovano', 'Obd_Readiness_Zazeh_O2S-FUNC_Podporovano', 'Obd_Readiness_Zazeh_O2S-HEAT_Otestovano', 'Obd_Readiness_Zazeh_O2S-HEAT_Podporovano', 'Obd_Readiness_Zazeh_SAS_Otestovano', 'Obd_Readiness_Zazeh_SAS_Podporovano', 'Obd_Readiness_Vznet_AC_Otestovano', 'Obd_Readiness_Vznet_AC_Podporovano', 'Obd_Readiness_Vznet_BOOST_Otestovano', 'Obd_Readiness_Vznet_BOOST_Podporovano', 'Obd_Readiness_Vznet_COMP_Otestovano', 'Obd_Readiness_Vznet_COMP_Podporovano', 'Obd_Readiness_Vznet_DPF_Otestovano', 'Obd_Readiness_Vznet_DPF_Podporovano', 'Obd_Readiness_Vznet_EGR-VVT_Otestovano', 'Obd_Readiness_Vznet_EGR-VVT_Podporovano', 'Obd_Readiness_Vznet_EGS_Otestovano', 'Obd_Readiness_Vznet_EGS_Podporovano', 'Obd_Readiness_Vznet_FUEL_Otestovano', 'Obd_Readiness_Vznet_FUEL_Podporovano', 'Obd_Readiness_Vznet_MISF_Otestovano', 'Obd_Readiness_Vznet_MISF_Podporovano', 'Obd_Readiness_Vznet_NMHC_Otestovano', 'Obd_Readiness_Vznet_NMHC_Podporovano', 'Obd_Readiness_Vznet_NOX_Otestovano', 'Obd_Readiness_Vznet_NOX_Podporovano', 'Obd_Readiness_Vznet_RESERVE_Otestovano', 'Obd_Readiness_Vznet_RESERVE_Podporovano', 'Benzin_OtackyVolnobezne_CO_Max_RucniZadani', 'Benzin_OtackyVolnobezne_HC_Max_RucniZadani', 'Benzin_OtackyVolnobezne_LAMBDA_Max_RucniZadani', 'Benzin_OtackyVolnobezne_LAMBDA_Min_RucniZadani', 'Benzin_OtackyVolnobezne_N_Max_RucniZadani', 'Benzin_OtackyVolnobezne_N_Min_RucniZadani', 'Benzin_OtackyZvysene_CO_Max_RucniZadani', 'Benzin_OtackyZvysene_HC_Max_RucniZadani', 'Benzin_OtackyZvysene_LAMBDA_Max_RucniZadani', 'Benzin_OtackyZvysene_LAMBDA_Min_RucniZadani', 'Benzin_OtackyZvysene_N_Max_RucniZadani', 'Benzin_OtackyZvysene_N_Min_RucniZadani', 'Nafta_MereniVznetLimit_CasAkcelerace_Max_RucniZadani', 'Nafta_MereniVznetLimit_KourivostRozpeti_Max_RucniZadani', 'Nafta_MereniVznetLimit_Kourivost_Max_RucniZadani', 'Nafta_MereniVznetLimit_OtackyPrebehove_Max_RucniZadani', 'Nafta_MereniVznetLimit_OtackyPrebehove_Min_RucniZadani', 'Nafta_MereniVznetLimit_OtackyVolnobezne_Max_RucniZadani', 'Nafta_MereniVznetLimit_OtackyVolnobezne_Min_RucniZadani']

# %% [markdown]
# # 9. Vyhodnocení na testovací sadě

# %%
# Aplikace fixního prahu a vyhodnocení na TESTOVACÍ SADĚ
y_test_proba = model.predict_proba(test_pool)[:, 1]
y_test_labels = test_pool.get_label()
y_test_pred = (y_test_proba >= best_overall_thr).astype(int)

# Výpočet matic (absolutní i relativní)
cm_abs = confusion_matrix(y_test_labels, y_test_pred)
cm_rel = confusion_matrix(y_test_labels, y_test_pred, normalize='all')

# Výpis ukazatelů
print(f"Použitý práh: {best_overall_thr:.4f}")
print(f"F1 skore (Test): {f1_score(y_test_labels, y_test_pred):.4f}")
print(f"log_loss (Test): {log_loss(y_test_labels, y_test_proba):.4f}")
print("\n--- Klasifikační report na TESTOVACÍ sadě (1 = Neúspěch) ---")
print(classification_report(y_test_labels, y_test_pred, target_names=['Úspěch (0)', 'Neúspěch (1)']))

# Vizualizace relativní matice záměn
fig, ax = plt.subplots(figsize=(6, 5))
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm_rel, 
    display_labels=['Úspěch (0)', 'Neúspěch (1)']
)
_ = disp.plot(cmap='Blues', ax=ax, values_format='.2%')
# Out:
# Použitý práh: 0.7411
# F1 skore (Test): 0.1535
# log_loss (Test): 0.5617
#
# --- Klasifikační report na TESTOVACÍ sadě (1 = Neúspěch) ---
#               precision    recall  f1-score   support
#
#   Úspěch (0)       0.98      0.94      0.96    946010
# Neúspěch (1)       0.11      0.26      0.15     25704
#
#     accuracy                           0.92    971714
#    macro avg       0.54      0.60      0.56    971714
# weighted avg       0.96      0.92      0.94    971714

# %%
# Příprava testovacích dat
current_cat_features_test = [c for c in cat_features if c in best_overall_features]
test_pool = Pool(X_test[best_overall_features], y_test, cat_features=current_cat_features_test)

# Predikce s optimálním prahem
y_test_proba = best_overall_model.predict_proba(test_pool)[:, 1]
y_test_pred = (y_test_proba >= best_overall_thr).astype(int)

# Výpočet důležitosti z testovací sady (LossFunctionChange)
fi_test = best_overall_model.get_feature_importance(
    data=test_pool, 
    type='LossFunctionChange',
    thread_count=-1
)

df_fi_test = pd.DataFrame({
    'feature': best_overall_features, 
    'importance': fi_test
}).sort_values(by='importance', ascending=False)

# Vizualizace
plt.figure(figsize=(10, 6))
sns.barplot(x='importance', y='feature', data=df_fi_test.head(20), palette='magma')
plt.title('Feature Importance na TESTOVACÍ sadě (LossFunctionChange)')
plt.grid(axis='x', alpha=0.3)
plt.show()

# Finální report
print(f"Test F1: {f1_score(y_test, y_test_pred):.4f}")
print(classification_report(y_test, y_test_pred))
# Out:
# /tmp/ipykernel_14880/69847376.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='importance', y='feature', data=df_fi_test.head(20), palette='magma')
# Test F1: 0.1524
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96    946010
#            1       0.11      0.27      0.15     25704
#
#     accuracy                           0.92    971714
#    macro avg       0.54      0.60      0.56    971714
# weighted avg       0.96      0.92      0.94    971714

# %% [markdown]
# # 10. Export vysledku

# %%
# Export dat do JSON souboru
export_data = {
    "confusion_matrix": {
        "values": cm_rel.tolist(),
        "labels": ['Úspěch (0)', 'Neúspěch (1)']
    },
    "feature_importance": [
        {
            "feature": row['feature'],
            "test_importance_loss_change": float(row['importance'])
        }
        for _, row in df_fi_test.iterrows()
    ]
}

with open('feature_importance_analysis.json', 'w', encoding='utf-8') as f:
    json.dump(export_data, f, ensure_ascii=False)

# %%
with open('data_splits.json', 'w') as f:
    json.dump({
        'train_indices': X_train.index.tolist(),
        'val_indices': X_val.index.tolist(),
        'test_indices': X_test.index.tolist()
    }, f)

with open('features_list.json', 'w') as f:
    json.dump(best_overall_features, f)

with open('threshold.json', 'w') as f:
    json.dump(best_overall_thr, f)

with open('features.json', 'w') as f:
    json.dump(best_overall_features, f)

with open('cat_features.json', 'w') as f:
    json.dump(cat_features, f)

with open('tuned_rf_hyperparameters.json', 'w') as f:
    json.dump(best_overall_model.get_params(), f)
